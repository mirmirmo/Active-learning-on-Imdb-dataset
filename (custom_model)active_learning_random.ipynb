# %% [markdown]
# ## Importing necessary libraries

# %%
import tensorflow as tf
import numpy as np
import re, os
import matplotlib.pyplot as plt
import pandas as pd
import sklearn

# %% [markdown]
# ## Getting data from Kaggle

# %%
import requests
import pandas as pd
import tarfile
import os

# Define the URL for the IMDb sentiment analysis dataset
url = "https://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz"
dataset_filename = "aclImdb_v1.tar.gz"

# Specify the download location
download_location = "./data/"

# Create the download directory if it doesn't exist
if not os.path.exists(download_location):
    os.makedirs(download_location)

# Download the dataset
response = requests.get(url)
with open(download_location + dataset_filename, 'wb') as f:
    f.write(response.content)

# Extract the downloaded file
with tarfile.open(download_location + dataset_filename, 'r:gz') as tar:
    tar.extractall(download_location)

# Define the path to the extracted dataset
dataset_path = download_location + "aclImdb/"

# Function to load the dataset into a Pandas DataFrame
def load_imdb_dataset(data_path):
    texts = []
    labels = []
    for category in ['train', 'test']:
        for sentiment in ['pos', 'neg']:
            folder_path = os.path.join(data_path, category, sentiment)
            for filename in os.listdir(folder_path):
                with open(os.path.join(folder_path, filename), 'r', encoding='utf-8') as file:
                    text = file.read()
                    texts.append(text)
                    labels.append(1 if sentiment == 'pos' else 0)
    return pd.DataFrame({'text': texts, 'label': labels})

# Load the dataset into a Pandas DataFrame
imdb_df = load_imdb_dataset(dataset_path)

# Display the first few rows of the DataFrame
print(imdb_df.head())
# Out:
#                                                 text  label
# 0  One of the biggest hits of 1926, Brown of Harv...      1
# 1  The delivery of some very humorous rude lines ...      1
# 2  I saw a preview of Freebird at the Isle of Man...      1
# 3  I loved this movie. It was almost the same as ...      1
# 4  This movies chronicles the life and times of W...      1

# %%
len(imdb_df)
# Out:
# 50000

# %%
from sklearn.model_selection import train_test_split

# Split the dataset into train, test, and validation sets
df_train, test_val_df = train_test_split(imdb_df, test_size=20000, random_state=42)
df_test, df_val = train_test_split(test_val_df, test_size=0.2, random_state=42)

# Display the shapes of the resulting DataFrames
print("Train set shape:", df_train.shape)
print("Test set shape:", df_test.shape)
print("Validation set shape:", df_val.shape)
# Out:
# Train set shape: (30000, 2)
# Test set shape: (16000, 2)
# Validation set shape: (4000, 2)

# %%
df_val.head()
# Out:
#                                                     text  label
# 26891  I would consider myself a fan of Dean Koontz; ...      1
# 25024  For a film by a first time director, this is a...      1
# 11666  The play Bell, Book, and Candle was a favorite...      1
# 40303  First, let me start off by saying this film SO...      0
# 18010  The Perfectly Stupid Weapon. I think the guys ...      0

# %%
df_test.head()
# Out:
#                                                     text  label
# 24835  From beginning to end, this is the most emotio...      0
# 28073  ...that maybe someday people will wake up to. ...      1
# 31069  i would give this movie an 8.5 or a 9. I thoug...      1
# 25736  A remarkable film, bringing to the surface all...      1
# 40229  Sigh. I'm baffled when I see a short like this...      0

# %%
df_train['label'].value_counts()
# Out:
# 0    15084
# 1    14916
# Name: label, dtype: int64

# %% [markdown]
# ## Preprocessing

# %%
# Cleaning/Preprocessing Helper function

def preprocess(s):
  s = re.sub(r'@[a-zA-Z0-9_.]+ ', '', str(s))
  s = re.sub(r'#[a-zA-Z0-9_.]+ ', '', str(s))
  s = re.sub(r'''[^a-zA-Z0-9?. ]+''', '', s)
  s = re.sub(r''''[' ']+''', " ", s)
  s = re.sub(r'(\w)\1{2,}',r'\1',s)
  s = s.lower().strip()
  return s

# %%
df_train['text'] = df_train['text'].apply(preprocess)
df_val['text'] = df_val['text'].apply(preprocess)
df_test['text'] = df_test['text'].apply(preprocess)

# %%
def get_data(df):
  zeros, ones = df[df['label']==0], df[df['label']==1]
  zero_text, zero_labels = zeros['text'].to_numpy(), zeros['label'].to_numpy()
  one_text, one_labels = ones['text'].to_numpy(), ones['label'].to_numpy()
  X, Y = np.concatenate((one_text,zero_text)), np.concatenate((one_labels,zero_labels))
  return X,Y

# %%
X_train,Y_train = get_data(df_train)
X_val,Y_val = get_data(df_val)
X_test,Y_test = get_data(df_test)

# %%
X_train.shape,X_val.shape,X_test.shape
# Out:
# ((30000,), (4000,), (16000,))

# %% [markdown]
# ## Creating the Model

# %%
# Instantiating the Tokenizer and creating sequences
tokenizer = tf.keras.preprocessing.text.Tokenizer(3000,oov_token=1)
tokenizer.fit_on_texts(X_train)
train_seq = tokenizer.texts_to_sequences(X_train)
val_seq = tokenizer.texts_to_sequences(X_val)
test_seq = tokenizer.texts_to_sequences(X_test)

# %%
# Padding all sequences
train_seq = tf.keras.preprocessing.sequence.pad_sequences(train_seq,maxlen=50,padding='post')
val_seq = tf.keras.preprocessing.sequence.pad_sequences(val_seq,maxlen=50,padding='post')
test_seq = tf.keras.preprocessing.sequence.pad_sequences(test_seq,maxlen=50,padding='post')

# %% [markdown]
# ## Creating the Model

# %%
# from tensorflow.keras.layers import Embedding,Dense,LSTM,Flatten,Dropout
# def create_model():
#   model = tf.keras.models.Sequential()
#   model.add(Embedding(3000,64))
#   model.add(LSTM(32))
#   model.add(Flatten())
#   model.add(Dense(64,activation='relu'))
#   model.add(Dropout(0.3))
#   model.add(Dense(32,activation='relu'))
#   model.add(Dropout(0.3))
#   model.add(Dense(4,activation='relu'))
#   model.add(Dense(1,activation='sigmoid'))
#   model.summary()
#   model.compile(optimizer=tf.keras.optimizers.Adam(0.0001),loss=tf.keras.losses.BinaryCrossentropy(),metrics=['accuracy'])
#   return model

# %%
import tensorflow as tf
from tensorflow.keras.layers import Embedding, LSTM, Conv1D, MaxPooling1D, Bidirectional, GlobalMaxPooling1D, Dense, Dropout

def create_model():
    model = tf.keras.models.Sequential()
    model.add(Embedding(input_dim=3000, output_dim=128))

    # Convolutional layers
    model.add(Conv1D(filters=128, kernel_size=3, activation='relu'))
    model.add(MaxPooling1D(pool_size=2))

    # Bidirectional LSTM layer
    model.add(Bidirectional(LSTM(units=64, return_sequences=True)))

    # Global Max Pooling layer
    model.add(GlobalMaxPooling1D())

    # Dense layers
    model.add(Dense(units=256, activation='relu'))
    model.add(Dropout(0.5))

    model.add(Dense(units=128, activation='relu'))
    model.add(Dropout(0.5))

    model.add(Dense(units=64, activation='relu'))
    model.add(Dropout(0.5))

    # Output layer
    model.add(Dense(units=1, activation='sigmoid'))

    model.summary()

    # Compile the model
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
                  loss=tf.keras.losses.BinaryCrossentropy(),
                  metrics=['accuracy'])

    return model

# %% [markdown]
# ## Full Model Training

# %%
# HELPER FUNCTION

def plot(history):
  plt.plot(history.history['loss'])
  plt.plot(history.history['val_loss'])
  plt.legend(['train_loss','val_loss'])
  plt.xlabel('Epochs')
  plt.ylabel('Loss')
  plt.show()

  plt.plot(history.history['accuracy'])
  plt.plot(history.history['val_accuracy'])
  plt.legend(['train_accuracy','val_accuracy'])
  plt.xlabel('Epochs')
  plt.ylabel('Accuracy')
  plt.show()

# %%
def train_full_model(train_seq,Y_train,val_seq,Y_val,test_seq,Y_test):
  model = create_model()
  history = model.fit(train_seq,Y_train,256,15,validation_data=(val_seq,Y_val),callbacks=[tf.keras.callbacks.ModelCheckpoint('FullModelCheckpoint.h5',save_best_only=True,verbose=1),tf.keras.callbacks.EarlyStopping(patience=6,verbose=1)])
  plot(history)
  model = tf.keras.models.load_model('FullModelCheckpoint.h5')
  print(model.evaluate(test_seq,Y_test))
  return model

# %% [markdown]
# ## Active Learning

# %%
# HELPER FUNCTIONS

def append_history(losses,val_losses,acc,val_acc,history):
  losses = losses + history.history['loss']
  val_losses = val_losses + history.history['val_loss']
  acc = acc + history.history['accuracy']
  val_acc = val_acc + history.history['val_accuracy']
  return losses,val_losses,acc,val_acc

def plot_merged_metrics(losses,val_losses,accuracies,val_accuracies):
  plt.plot(losses)
  plt.plot(val_losses)
  plt.legend(['train_loss','val_loss'])
  plt.xlabel('Epochs')
  plt.ylabel('Loss')
  plt.show()

  plt.plot(accuracies)
  plt.plot(val_accuracies)
  plt.legend(['train_accuracy','val_accuracy'])
  plt.xlabel('Epochs')
  plt.ylabel('Accuracy')
  plt.show()

# %%
import numpy as np
import tensorflow as tf
import collections



def train_small_models(train_features, train_labels, pool_features, pool_labels, val_seq, Y_val, test_seq, Y_test, iters=3, sampling_size=2000):

    losses, val_losses, accuracies, val_accuracies = [], [], [], []

    for iter_n in range(iters):
        # Create a new model for each iteration
        model = create_model()
        checkpoint = tf.keras.callbacks.ModelCheckpoint(f'Checkpoint_{iter_n}.h5', save_best_only=True, verbose=1)

        print(f"Starting to train with {train_features.shape[0]} labeled samples")

        history = model.fit(train_features, train_labels, batch_size=256, epochs=15,
                            validation_data=(val_seq, Y_val),
                            callbacks=[checkpoint])

        losses, val_losses, accuracies, val_accuracies = append_history(losses, val_losses, accuracies, val_accuracies, history)

        # Evaluate and print accuracy on test data
        test_accuracy = model.evaluate(test_seq, Y_test)[1]
        print(f"Accuracy on test data after iteration {iter_n}: {test_accuracy}, Number of labeled samples: {train_features.shape[0]}")

        # Getting predictions from the trained model
        predictions = model.predict(test_seq)
        rounded = np.where(predictions > 0.5, 1, 0)

        # Count number of ones and zeros incorrectly classified
        counter = collections.Counter(Y_test[rounded.squeeze() != Y_test.squeeze()])

        # Find ratio of ones to zeros. If all samples are correctly classified (Major overfitting),
        # then we set the ratio to 0.5
        if counter[0] != 0 and counter[1] != 0:
            total = counter[0] + counter[1]
            sample_ratio = counter[0] / total if counter[0] > counter[1] else counter[1] / total
        else:
            sample_ratio = 0.5

        # Randomly sample from the entire pool
        sample = np.concatenate((np.random.choice(len(pool_labels), int(sample_ratio * sampling_size), replace=False),
                                 np.random.choice(len(pool_labels), int(sampling_size * (1 - sample_ratio)), replace=False)))
        np.random.shuffle(sample)

        # Get new values from the pool
        update_f = pool_features[sample]
        update_l = pool_labels[sample]

        # Remove the chosen samples from the pool
        pool_features = np.delete(pool_features, sample, axis=0)
        pool_labels = np.delete(pool_labels, sample)

        # Add the sampled entries to the original data
        train_features = np.vstack((train_features, update_f))
        train_labels = np.hstack((train_labels, update_l))

    plot_merged_metrics(losses, val_losses, accuracies, val_accuracies)

    return model

# %% [markdown]
# ## Ensembling

# %%
# # Splitting Data into Oracle Set(Unlabelled set) and Original Training set
import sklearn.model_selection
train_features,pool_features,train_labels,pool_labels = sklearn.model_selection.train_test_split(train_seq,Y_train,test_size=29000,stratify=Y_train)
train_features.shape,pool_features.shape
# Out:
# ((1000, 50), (29000, 50))

# %%
# Training 3 Active Learning Models for Ensembling
al_model1 = train_small_models(train_features,train_labels,pool_features,pool_labels,val_seq,Y_val,test_seq,Y_test,iters=5, sampling_size=1000)
# al_model2 = train_small_models(train_features,train_labels,pool_features,pool_labels,val_seq,Y_val,test_seq,Y_test)
# al_model3 = train_small_models(train_features,train_labels,pool_features,pool_labels,val_seq,Y_val,test_seq,Y_test)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, None, 128)         384000
#
#  conv1d (Conv1D)             (None, None, 128)         49280
#
#  max_pooling1d (MaxPooling1  (None, None, 128)         0
#  D)
#
#  bidirectional (Bidirection  (None, None, 128)         98816
#  al)
#
#  global_max_pooling1d (Glob  (None, 128)               0
#  alMaxPooling1D)
#
#  dense (Dense)               (None, 256)               33024
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 64)                8256
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 606337 (2.31 MB)
# Trainable params: 606337 (2.31 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Starting to train with 1000 labeled samples
# Epoch 1/15
# 4/4 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.5070
# Epoch 1: val_loss improved from inf to 0.69302, saving model to Checkpoint_0.h5
# 4/4 [==============================] - 10s 1s/step - loss: 0.6932 - accuracy: 0.5070 - val_loss: 0.6930 - val_accuracy: 0.5132
# Epoch 2/15
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 4/4 [==============================] - ETA: 0s - loss: 0.6935 - accuracy: 0.4880
# Epoch 2: val_loss did not improve from 0.69302
# 4/4 [==============================] - 2s 646ms/step - loss: 0.6935 - accuracy: 0.4880 - val_loss: 0.6930 - val_accuracy: 0.5132
# Epoch 3/15
# 4/4 [==============================] - ETA: 0s - loss: 0.6929 - accuracy: 0.5070
# Epoch 3: val_loss improved from 0.69302 to 0.69302, saving model to Checkpoint_0.h5
# 4/4 [==============================] - 2s 666ms/step - loss: 0.6929 - accuracy: 0.5070 - val_loss: 0.6930 - val_accuracy: 0.5132
# Epoch 4/15
# 4/4 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4930
# Epoch 4: val_loss improved from 0.69302 to 0.69301, saving model to Checkpoint_0.h5
# 4/4 [==============================] - 2s 667ms/step - loss: 0.6932 - accuracy: 0.4930 - val_loss: 0.6930 - val_accuracy: 0.5132
# Epoch 5/15
# 4/4 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4870
# Epoch 5: val_loss did not improve from 0.69301
# 4/4 [==============================] - 3s 819ms/step - loss: 0.6932 - accuracy: 0.4870 - val_loss: 0.6930 - val_accuracy: 0.5132
# Epoch 6/15
# 4/4 [==============================] - ETA: 0s - loss: 0.6937 - accuracy: 0.4740
# Epoch 6: val_loss did not improve from 0.69301
# 4/4 [==============================] - 2s 614ms/step - loss: 0.6937 - accuracy: 0.4740 - val_loss: 0.6930 - val_accuracy: 0.5142
# Epoch 7/15
# 4/4 [==============================] - ETA: 0s - loss: 0.6930 - accuracy: 0.5000
# Epoch 7: val_loss did not improve from 0.69301
# 4/4 [==============================] - 2s 551ms/step - loss: 0.6930 - accuracy: 0.5000 - val_loss: 0.6930 - val_accuracy: 0.5163
# Epoch 8/15
# 4/4 [==============================] - ETA: 0s - loss: 0.6933 - accuracy: 0.5020
# Epoch 8: val_loss did not improve from 0.69301
# 4/4 [==============================] - 2s 640ms/step - loss: 0.6933 - accuracy: 0.5020 - val_loss: 0.6930 - val_accuracy: 0.5165
# Epoch 9/15
# 4/4 [==============================] - ETA: 0s - loss: 0.6934 - accuracy: 0.5160
# Epoch 9: val_loss did not improve from 0.69301
# 4/4 [==============================] - 4s 1s/step - loss: 0.6934 - accuracy: 0.5160 - val_loss: 0.6930 - val_accuracy: 0.5235
# Epoch 10/15
# 4/4 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4980
# Epoch 10: val_loss did not improve from 0.69301
# 4/4 [==============================] - 3s 1s/step - loss: 0.6932 - accuracy: 0.4980 - val_loss: 0.6930 - val_accuracy: 0.5343
# Epoch 11/15
# 4/4 [==============================] - ETA: 0s - loss: 0.6928 - accuracy: 0.5320
# Epoch 11: val_loss did not improve from 0.69301
# 4/4 [==============================] - 2s 566ms/step - loss: 0.6928 - accuracy: 0.5320 - val_loss: 0.6930 - val_accuracy: 0.5383
# Epoch 12/15
# 4/4 [==============================] - ETA: 0s - loss: 0.6931 - accuracy: 0.5100
# Epoch 12: val_loss did not improve from 0.69301
# 4/4 [==============================] - 2s 560ms/step - loss: 0.6931 - accuracy: 0.5100 - val_loss: 0.6930 - val_accuracy: 0.5462
# Epoch 13/15
# 4/4 [==============================] - ETA: 0s - loss: 0.6920 - accuracy: 0.5320
# Epoch 13: val_loss did not improve from 0.69301
# 4/4 [==============================] - 2s 554ms/step - loss: 0.6920 - accuracy: 0.5320 - val_loss: 0.6930 - val_accuracy: 0.5368
# Epoch 14/15
# 4/4 [==============================] - ETA: 0s - loss: 0.6928 - accuracy: 0.5320
# Epoch 14: val_loss did not improve from 0.69301
# 4/4 [==============================] - 3s 1s/step - loss: 0.6928 - accuracy: 0.5320 - val_loss: 0.6930 - val_accuracy: 0.5332
# Epoch 15/15
# 4/4 [==============================] - ETA: 0s - loss: 0.6930 - accuracy: 0.5090
# Epoch 15: val_loss did not improve from 0.69301
# 4/4 [==============================] - 4s 1s/step - loss: 0.6930 - accuracy: 0.5090 - val_loss: 0.6930 - val_accuracy: 0.5337
# 500/500 [==============================] - 7s 14ms/step - loss: 0.6930 - accuracy: 0.5433
# Accuracy on test data after iteration 0: 0.5432500243186951, Number of labeled samples: 1000
# 500/500 [==============================] - 8s 13ms/step
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, None, 128)         384000
#
#  conv1d_1 (Conv1D)           (None, None, 128)         49280
#
#  max_pooling1d_1 (MaxPoolin  (None, None, 128)         0
#  g1D)
#
#  bidirectional_1 (Bidirecti  (None, None, 128)         98816
#  onal)
#
#  global_max_pooling1d_1 (Gl  (None, 128)               0
#  obalMaxPooling1D)
#
#  dense_4 (Dense)             (None, 256)               33024
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_5 (Dense)             (None, 128)               32896
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  dense_6 (Dense)             (None, 64)                8256
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_7 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 606337 (2.31 MB)
# Trainable params: 606337 (2.31 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Starting to train with 1999 labeled samples
# Epoch 1/15
# 8/8 [==============================] - ETA: 0s - loss: 0.6933 - accuracy: 0.4922
# Epoch 1: val_loss improved from inf to 0.69303, saving model to Checkpoint_1.h5
# 8/8 [==============================] - 9s 516ms/step - loss: 0.6933 - accuracy: 0.4922 - val_loss: 0.6930 - val_accuracy: 0.5128
# Epoch 2/15
# 8/8 [==============================] - ETA: 0s - loss: 0.6930 - accuracy: 0.5048
# Epoch 2: val_loss did not improve from 0.69303
# 8/8 [==============================] - 5s 617ms/step - loss: 0.6930 - accuracy: 0.5048 - val_loss: 0.6930 - val_accuracy: 0.5160
# Epoch 3/15
# 8/8 [==============================] - ETA: 0s - loss: 0.6930 - accuracy: 0.5163
# Epoch 3: val_loss did not improve from 0.69303
# 8/8 [==============================] - 3s 398ms/step - loss: 0.6930 - accuracy: 0.5163 - val_loss: 0.6931 - val_accuracy: 0.5257
# Epoch 4/15
# 8/8 [==============================] - ETA: 0s - loss: 0.6927 - accuracy: 0.5213
# Epoch 4: val_loss did not improve from 0.69303
# 8/8 [==============================] - 3s 394ms/step - loss: 0.6927 - accuracy: 0.5213 - val_loss: 0.6931 - val_accuracy: 0.5355
# Epoch 5/15
# 8/8 [==============================] - ETA: 0s - loss: 0.6933 - accuracy: 0.5008
# Epoch 5: val_loss did not improve from 0.69303
# 8/8 [==============================] - 3s 393ms/step - loss: 0.6933 - accuracy: 0.5008 - val_loss: 0.6931 - val_accuracy: 0.4978
# Epoch 6/15
# 8/8 [==============================] - ETA: 0s - loss: 0.6926 - accuracy: 0.5308
# Epoch 6: val_loss did not improve from 0.69303
# 8/8 [==============================] - 4s 534ms/step - loss: 0.6926 - accuracy: 0.5308 - val_loss: 0.6931 - val_accuracy: 0.4900
# Epoch 7/15
# 8/8 [==============================] - ETA: 0s - loss: 0.6925 - accuracy: 0.5208
# Epoch 7: val_loss did not improve from 0.69303
# 8/8 [==============================] - 3s 353ms/step - loss: 0.6925 - accuracy: 0.5208 - val_loss: 0.6931 - val_accuracy: 0.4875
# Epoch 8/15
# 8/8 [==============================] - ETA: 0s - loss: 0.6929 - accuracy: 0.5128
# Epoch 8: val_loss did not improve from 0.69303
# 8/8 [==============================] - 3s 400ms/step - loss: 0.6929 - accuracy: 0.5128 - val_loss: 0.6931 - val_accuracy: 0.4865
# Epoch 9/15
# 8/8 [==============================] - ETA: 0s - loss: 0.6928 - accuracy: 0.5233
# Epoch 9: val_loss did not improve from 0.69303
# 8/8 [==============================] - 3s 400ms/step - loss: 0.6928 - accuracy: 0.5233 - val_loss: 0.6931 - val_accuracy: 0.4865
# Epoch 10/15
# 8/8 [==============================] - ETA: 0s - loss: 0.6924 - accuracy: 0.5333
# Epoch 10: val_loss did not improve from 0.69303
# 8/8 [==============================] - 4s 524ms/step - loss: 0.6924 - accuracy: 0.5333 - val_loss: 0.6931 - val_accuracy: 0.4865
# Epoch 11/15
# 8/8 [==============================] - ETA: 0s - loss: 0.6918 - accuracy: 0.5443
# Epoch 11: val_loss improved from 0.69303 to 0.69299, saving model to Checkpoint_1.h5
# 8/8 [==============================] - 3s 407ms/step - loss: 0.6918 - accuracy: 0.5443 - val_loss: 0.6930 - val_accuracy: 0.4865
# Epoch 12/15
# 8/8 [==============================] - ETA: 0s - loss: 0.6924 - accuracy: 0.5278
# Epoch 12: val_loss improved from 0.69299 to 0.69291, saving model to Checkpoint_1.h5
# 8/8 [==============================] - 3s 368ms/step - loss: 0.6924 - accuracy: 0.5278 - val_loss: 0.6929 - val_accuracy: 0.4868
# Epoch 13/15
# 8/8 [==============================] - ETA: 0s - loss: 0.6926 - accuracy: 0.5438
# Epoch 13: val_loss improved from 0.69291 to 0.69282, saving model to Checkpoint_1.h5
# 8/8 [==============================] - 3s 366ms/step - loss: 0.6926 - accuracy: 0.5438 - val_loss: 0.6928 - val_accuracy: 0.4877
# Epoch 14/15
# 8/8 [==============================] - ETA: 0s - loss: 0.6918 - accuracy: 0.5268
# Epoch 14: val_loss did not improve from 0.69282
# 8/8 [==============================] - 5s 704ms/step - loss: 0.6918 - accuracy: 0.5268 - val_loss: 0.6929 - val_accuracy: 0.4865
# Epoch 15/15
# 8/8 [==============================] - ETA: 0s - loss: 0.6913 - accuracy: 0.5533
# Epoch 15: val_loss improved from 0.69282 to 0.69259, saving model to Checkpoint_1.h5
# 8/8 [==============================] - 3s 371ms/step - loss: 0.6913 - accuracy: 0.5533 - val_loss: 0.6926 - val_accuracy: 0.4890
# 500/500 [==============================] - 7s 14ms/step - loss: 0.6923 - accuracy: 0.5009
# Accuracy on test data after iteration 1: 0.5008749961853027, Number of labeled samples: 1999
# 500/500 [==============================] - 7s 13ms/step
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, None, 128)         384000
#
#  conv1d_2 (Conv1D)           (None, None, 128)         49280
#
#  max_pooling1d_2 (MaxPoolin  (None, None, 128)         0
#  g1D)
#
#  bidirectional_2 (Bidirecti  (None, None, 128)         98816
#  onal)
#
#  global_max_pooling1d_2 (Gl  (None, 128)               0
#  obalMaxPooling1D)
#
#  dense_8 (Dense)             (None, 256)               33024
#
#  dropout_6 (Dropout)         (None, 256)               0
#
#  dense_9 (Dense)             (None, 128)               32896
#
#  dropout_7 (Dropout)         (None, 128)               0
#
#  dense_10 (Dense)            (None, 64)                8256
#
#  dropout_8 (Dropout)         (None, 64)                0
#
#  dense_11 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 606337 (2.31 MB)
# Trainable params: 606337 (2.31 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Starting to train with 2998 labeled samples
# Epoch 1/15
# 12/12 [==============================] - ETA: 0s - loss: 0.6930 - accuracy: 0.5113
# Epoch 1: val_loss improved from inf to 0.69333, saving model to Checkpoint_2.h5
# 12/12 [==============================] - 11s 399ms/step - loss: 0.6930 - accuracy: 0.5113 - val_loss: 0.6933 - val_accuracy: 0.4868
# Epoch 2/15
# 12/12 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.5057
# Epoch 2: val_loss improved from 0.69333 to 0.69329, saving model to Checkpoint_2.h5
# 12/12 [==============================] - 4s 350ms/step - loss: 0.6932 - accuracy: 0.5057 - val_loss: 0.6933 - val_accuracy: 0.4868
# Epoch 3/15
# 12/12 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.5013
# Epoch 3: val_loss improved from 0.69329 to 0.69327, saving model to Checkpoint_2.h5
# 12/12 [==============================] - 4s 349ms/step - loss: 0.6932 - accuracy: 0.5013 - val_loss: 0.6933 - val_accuracy: 0.4868
# Epoch 4/15
# 12/12 [==============================] - ETA: 0s - loss: 0.6931 - accuracy: 0.5067
# Epoch 4: val_loss improved from 0.69327 to 0.69325, saving model to Checkpoint_2.h5
# 12/12 [==============================] - 5s 447ms/step - loss: 0.6931 - accuracy: 0.5067 - val_loss: 0.6933 - val_accuracy: 0.4868
# Epoch 5/15
# 12/12 [==============================] - ETA: 0s - loss: 0.6928 - accuracy: 0.5070
# Epoch 5: val_loss improved from 0.69325 to 0.69322, saving model to Checkpoint_2.h5
# 12/12 [==============================] - 5s 477ms/step - loss: 0.6928 - accuracy: 0.5070 - val_loss: 0.6932 - val_accuracy: 0.4868
# Epoch 6/15
# 12/12 [==============================] - ETA: 0s - loss: 0.6925 - accuracy: 0.5110
# Epoch 6: val_loss did not improve from 0.69322
# 12/12 [==============================] - 4s 302ms/step - loss: 0.6925 - accuracy: 0.5110 - val_loss: 0.6932 - val_accuracy: 0.4868
# Epoch 7/15
# 12/12 [==============================] - ETA: 0s - loss: 0.6931 - accuracy: 0.5003
# Epoch 7: val_loss did not improve from 0.69322
# 12/12 [==============================] - 4s 300ms/step - loss: 0.6931 - accuracy: 0.5003 - val_loss: 0.6932 - val_accuracy: 0.4868
# Epoch 8/15
# 12/12 [==============================] - ETA: 0s - loss: 0.6925 - accuracy: 0.5213
# Epoch 8: val_loss improved from 0.69322 to 0.69321, saving model to Checkpoint_2.h5
# 12/12 [==============================] - 5s 473ms/step - loss: 0.6925 - accuracy: 0.5213 - val_loss: 0.6932 - val_accuracy: 0.4868
# Epoch 9/15
# 12/12 [==============================] - ETA: 0s - loss: 0.6927 - accuracy: 0.5093
# Epoch 9: val_loss improved from 0.69321 to 0.69316, saving model to Checkpoint_2.h5
# 12/12 [==============================] - 4s 309ms/step - loss: 0.6927 - accuracy: 0.5093 - val_loss: 0.6932 - val_accuracy: 0.4868
# Epoch 10/15
# 12/12 [==============================] - ETA: 0s - loss: 0.6923 - accuracy: 0.5217
# Epoch 10: val_loss improved from 0.69316 to 0.69303, saving model to Checkpoint_2.h5
# 12/12 [==============================] - 4s 335ms/step - loss: 0.6923 - accuracy: 0.5217 - val_loss: 0.6930 - val_accuracy: 0.4868
# Epoch 11/15
# 12/12 [==============================] - ETA: 0s - loss: 0.6914 - accuracy: 0.5347
# Epoch 11: val_loss improved from 0.69303 to 0.69280, saving model to Checkpoint_2.h5
# 12/12 [==============================] - 6s 499ms/step - loss: 0.6914 - accuracy: 0.5347 - val_loss: 0.6928 - val_accuracy: 0.4868
# Epoch 12/15
# 12/12 [==============================] - ETA: 0s - loss: 0.6915 - accuracy: 0.5354
# Epoch 12: val_loss improved from 0.69280 to 0.69270, saving model to Checkpoint_2.h5
# 12/12 [==============================] - 4s 308ms/step - loss: 0.6915 - accuracy: 0.5354 - val_loss: 0.6927 - val_accuracy: 0.4870
# Epoch 13/15
# 12/12 [==============================] - ETA: 0s - loss: 0.6912 - accuracy: 0.5314
# Epoch 13: val_loss improved from 0.69270 to 0.69201, saving model to Checkpoint_2.h5
# 12/12 [==============================] - 4s 338ms/step - loss: 0.6912 - accuracy: 0.5314 - val_loss: 0.6920 - val_accuracy: 0.4900
# Epoch 14/15
# 12/12 [==============================] - ETA: 0s - loss: 0.6901 - accuracy: 0.5554
# Epoch 14: val_loss improved from 0.69201 to 0.69100, saving model to Checkpoint_2.h5
# 12/12 [==============================] - 5s 429ms/step - loss: 0.6901 - accuracy: 0.5554 - val_loss: 0.6910 - val_accuracy: 0.5300
# Epoch 15/15
# 12/12 [==============================] - ETA: 0s - loss: 0.6893 - accuracy: 0.5444
# Epoch 15: val_loss improved from 0.69100 to 0.68963, saving model to Checkpoint_2.h5
# 12/12 [==============================] - 4s 342ms/step - loss: 0.6893 - accuracy: 0.5444 - val_loss: 0.6896 - val_accuracy: 0.5347
# 500/500 [==============================] - 8s 16ms/step - loss: 0.6890 - accuracy: 0.5429
# Accuracy on test data after iteration 2: 0.5429375171661377, Number of labeled samples: 2998
# 500/500 [==============================] - 9s 16ms/step
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_3 (Embedding)     (None, None, 128)         384000
#
#  conv1d_3 (Conv1D)           (None, None, 128)         49280
#
#  max_pooling1d_3 (MaxPoolin  (None, None, 128)         0
#  g1D)
#
#  bidirectional_3 (Bidirecti  (None, None, 128)         98816
#  onal)
#
#  global_max_pooling1d_3 (Gl  (None, 128)               0
#  obalMaxPooling1D)
#
#  dense_12 (Dense)            (None, 256)               33024
#
#  dropout_9 (Dropout)         (None, 256)               0
#
#  dense_13 (Dense)            (None, 128)               32896
#
#  dropout_10 (Dropout)        (None, 128)               0
#
#  dense_14 (Dense)            (None, 64)                8256
#
#  dropout_11 (Dropout)        (None, 64)                0
#
#  dense_15 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 606337 (2.31 MB)
# Trainable params: 606337 (2.31 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Starting to train with 3997 labeled samples
# Epoch 1/15
# 16/16 [==============================] - ETA: 0s - loss: 0.6931 - accuracy: 0.5064
# Epoch 1: val_loss improved from inf to 0.69345, saving model to Checkpoint_3.h5
# 16/16 [==============================] - 12s 467ms/step - loss: 0.6931 - accuracy: 0.5064 - val_loss: 0.6935 - val_accuracy: 0.4868
# Epoch 2/15
# 16/16 [==============================] - ETA: 0s - loss: 0.6931 - accuracy: 0.5014
# Epoch 2: val_loss improved from 0.69345 to 0.69342, saving model to Checkpoint_3.h5
# 16/16 [==============================] - 5s 292ms/step - loss: 0.6931 - accuracy: 0.5014 - val_loss: 0.6934 - val_accuracy: 0.4868
# Epoch 3/15
# 16/16 [==============================] - ETA: 0s - loss: 0.6931 - accuracy: 0.5056
# Epoch 3: val_loss improved from 0.69342 to 0.69341, saving model to Checkpoint_3.h5
# 16/16 [==============================] - 6s 366ms/step - loss: 0.6931 - accuracy: 0.5056 - val_loss: 0.6934 - val_accuracy: 0.4868
# Epoch 4/15
# 16/16 [==============================] - ETA: 0s - loss: 0.6925 - accuracy: 0.5269
# Epoch 4: val_loss improved from 0.69341 to 0.69334, saving model to Checkpoint_3.h5
# 16/16 [==============================] - 5s 305ms/step - loss: 0.6925 - accuracy: 0.5269 - val_loss: 0.6933 - val_accuracy: 0.4868
# Epoch 5/15
# 16/16 [==============================] - ETA: 0s - loss: 0.6929 - accuracy: 0.5119
# Epoch 5: val_loss did not improve from 0.69334
# 16/16 [==============================] - 5s 301ms/step - loss: 0.6929 - accuracy: 0.5119 - val_loss: 0.6934 - val_accuracy: 0.4868
# Epoch 6/15
# 16/16 [==============================] - ETA: 0s - loss: 0.6928 - accuracy: 0.5174
# Epoch 6: val_loss did not improve from 0.69334
# 16/16 [==============================] - 6s 346ms/step - loss: 0.6928 - accuracy: 0.5174 - val_loss: 0.6934 - val_accuracy: 0.4868
# Epoch 7/15
# 16/16 [==============================] - ETA: 0s - loss: 0.6926 - accuracy: 0.5119
# Epoch 7: val_loss did not improve from 0.69334
# 16/16 [==============================] - 5s 299ms/step - loss: 0.6926 - accuracy: 0.5119 - val_loss: 0.6934 - val_accuracy: 0.4868
# Epoch 8/15
# 16/16 [==============================] - ETA: 0s - loss: 0.6925 - accuracy: 0.5091
# Epoch 8: val_loss improved from 0.69334 to 0.69324, saving model to Checkpoint_3.h5
# 16/16 [==============================] - 6s 380ms/step - loss: 0.6925 - accuracy: 0.5091 - val_loss: 0.6932 - val_accuracy: 0.4868
# Epoch 9/15
# 16/16 [==============================] - ETA: 0s - loss: 0.6920 - accuracy: 0.5171
# Epoch 9: val_loss improved from 0.69324 to 0.69318, saving model to Checkpoint_3.h5
# 16/16 [==============================] - 5s 303ms/step - loss: 0.6920 - accuracy: 0.5171 - val_loss: 0.6932 - val_accuracy: 0.4868
# Epoch 10/15
# 16/16 [==============================] - ETA: 0s - loss: 0.6918 - accuracy: 0.5226
# Epoch 10: val_loss improved from 0.69318 to 0.69275, saving model to Checkpoint_3.h5
# 16/16 [==============================] - 6s 391ms/step - loss: 0.6918 - accuracy: 0.5226 - val_loss: 0.6927 - val_accuracy: 0.4868
# Epoch 11/15
# 16/16 [==============================] - ETA: 0s - loss: 0.6909 - accuracy: 0.5279
# Epoch 11: val_loss improved from 0.69275 to 0.69233, saving model to Checkpoint_3.h5
# 16/16 [==============================] - 4s 281ms/step - loss: 0.6909 - accuracy: 0.5279 - val_loss: 0.6923 - val_accuracy: 0.4868
# Epoch 12/15
# 16/16 [==============================] - ETA: 0s - loss: 0.6900 - accuracy: 0.5419
# Epoch 12: val_loss improved from 0.69233 to 0.69118, saving model to Checkpoint_3.h5
# 16/16 [==============================] - 4s 284ms/step - loss: 0.6900 - accuracy: 0.5419 - val_loss: 0.6912 - val_accuracy: 0.4905
# Epoch 13/15
# 16/16 [==============================] - ETA: 0s - loss: 0.6880 - accuracy: 0.5529
# Epoch 13: val_loss improved from 0.69118 to 0.68910, saving model to Checkpoint_3.h5
# 16/16 [==============================] - 6s 382ms/step - loss: 0.6880 - accuracy: 0.5529 - val_loss: 0.6891 - val_accuracy: 0.5077
# Epoch 14/15
# 16/16 [==============================] - ETA: 0s - loss: 0.6826 - accuracy: 0.6012
# Epoch 14: val_loss improved from 0.68910 to 0.68374, saving model to Checkpoint_3.h5
# 16/16 [==============================] - 5s 287ms/step - loss: 0.6826 - accuracy: 0.6012 - val_loss: 0.6837 - val_accuracy: 0.5585
# Epoch 15/15
# 16/16 [==============================] - ETA: 0s - loss: 0.6708 - accuracy: 0.6385
# Epoch 15: val_loss improved from 0.68374 to 0.66732, saving model to Checkpoint_3.h5
# 16/16 [==============================] - 6s 413ms/step - loss: 0.6708 - accuracy: 0.6385 - val_loss: 0.6673 - val_accuracy: 0.6335
# 500/500 [==============================] - 8s 15ms/step - loss: 0.6649 - accuracy: 0.6453
# Accuracy on test data after iteration 3: 0.645312488079071, Number of labeled samples: 3997
# 500/500 [==============================] - 8s 14ms/step
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_4 (Embedding)     (None, None, 128)         384000
#
#  conv1d_4 (Conv1D)           (None, None, 128)         49280
#
#  max_pooling1d_4 (MaxPoolin  (None, None, 128)         0
#  g1D)
#
#  bidirectional_4 (Bidirecti  (None, None, 128)         98816
#  onal)
#
#  global_max_pooling1d_4 (Gl  (None, 128)               0
#  obalMaxPooling1D)
#
#  dense_16 (Dense)            (None, 256)               33024
#
#  dropout_12 (Dropout)        (None, 256)               0
#
#  dense_17 (Dense)            (None, 128)               32896
#
#  dropout_13 (Dropout)        (None, 128)               0
#
#  dense_18 (Dense)            (None, 64)                8256
#
#  dropout_14 (Dropout)        (None, 64)                0
#
#  dense_19 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 606337 (2.31 MB)
# Trainable params: 606337 (2.31 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Starting to train with 4996 labeled samples
# Epoch 1/15
# 20/20 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.5024
# Epoch 1: val_loss improved from inf to 0.69315, saving model to Checkpoint_4.h5
# 20/20 [==============================] - 15s 412ms/step - loss: 0.6932 - accuracy: 0.5024 - val_loss: 0.6932 - val_accuracy: 0.4940
# Epoch 2/15
# 20/20 [==============================] - ETA: 0s - loss: 0.6930 - accuracy: 0.5110
# Epoch 2: val_loss did not improve from 0.69315
# 20/20 [==============================] - 6s 282ms/step - loss: 0.6930 - accuracy: 0.5110 - val_loss: 0.6932 - val_accuracy: 0.4868
# Epoch 3/15
# 20/20 [==============================] - ETA: 0s - loss: 0.6931 - accuracy: 0.5086
# Epoch 3: val_loss did not improve from 0.69315
# 20/20 [==============================] - 7s 369ms/step - loss: 0.6931 - accuracy: 0.5086 - val_loss: 0.6932 - val_accuracy: 0.4868
# Epoch 4/15
# 20/20 [==============================] - ETA: 0s - loss: 0.6929 - accuracy: 0.5116
# Epoch 4: val_loss did not improve from 0.69315
# 20/20 [==============================] - 6s 288ms/step - loss: 0.6929 - accuracy: 0.5116 - val_loss: 0.6932 - val_accuracy: 0.4868
# Epoch 5/15
# 20/20 [==============================] - ETA: 0s - loss: 0.6930 - accuracy: 0.5136
# Epoch 5: val_loss improved from 0.69315 to 0.69312, saving model to Checkpoint_4.h5
# 20/20 [==============================] - 7s 380ms/step - loss: 0.6930 - accuracy: 0.5136 - val_loss: 0.6931 - val_accuracy: 0.4868
# Epoch 6/15
# 20/20 [==============================] - ETA: 0s - loss: 0.6928 - accuracy: 0.5140
# Epoch 6: val_loss improved from 0.69312 to 0.69299, saving model to Checkpoint_4.h5
# 20/20 [==============================] - 6s 291ms/step - loss: 0.6928 - accuracy: 0.5140 - val_loss: 0.6930 - val_accuracy: 0.4900
# Epoch 7/15
# 20/20 [==============================] - ETA: 0s - loss: 0.6927 - accuracy: 0.5212
# Epoch 7: val_loss improved from 0.69299 to 0.69275, saving model to Checkpoint_4.h5
# 20/20 [==============================] - 7s 340ms/step - loss: 0.6927 - accuracy: 0.5212 - val_loss: 0.6928 - val_accuracy: 0.5048
# Epoch 8/15
# 20/20 [==============================] - ETA: 0s - loss: 0.6925 - accuracy: 0.5284
# Epoch 8: val_loss improved from 0.69275 to 0.69236, saving model to Checkpoint_4.h5
# 20/20 [==============================] - 6s 288ms/step - loss: 0.6925 - accuracy: 0.5284 - val_loss: 0.6924 - val_accuracy: 0.5288
# Epoch 9/15
# 20/20 [==============================] - ETA: 0s - loss: 0.6921 - accuracy: 0.5300
# Epoch 9: val_loss improved from 0.69236 to 0.69175, saving model to Checkpoint_4.h5
# 20/20 [==============================] - 8s 395ms/step - loss: 0.6921 - accuracy: 0.5300 - val_loss: 0.6918 - val_accuracy: 0.5655
# Epoch 10/15
# 20/20 [==============================] - ETA: 0s - loss: 0.6909 - accuracy: 0.5562
# Epoch 10: val_loss improved from 0.69175 to 0.69095, saving model to Checkpoint_4.h5
# 20/20 [==============================] - 6s 288ms/step - loss: 0.6909 - accuracy: 0.5562 - val_loss: 0.6909 - val_accuracy: 0.5455
# Epoch 11/15
# 20/20 [==============================] - ETA: 0s - loss: 0.6884 - accuracy: 0.5949
# Epoch 11: val_loss improved from 0.69095 to 0.68740, saving model to Checkpoint_4.h5
# 20/20 [==============================] - 7s 347ms/step - loss: 0.6884 - accuracy: 0.5949 - val_loss: 0.6874 - val_accuracy: 0.6252
# Epoch 12/15
# 20/20 [==============================] - ETA: 0s - loss: 0.6833 - accuracy: 0.6305
# Epoch 12: val_loss improved from 0.68740 to 0.67812, saving model to Checkpoint_4.h5
# 20/20 [==============================] - 6s 292ms/step - loss: 0.6833 - accuracy: 0.6305 - val_loss: 0.6781 - val_accuracy: 0.6450
# Epoch 13/15
# 20/20 [==============================] - ETA: 0s - loss: 0.6633 - accuracy: 0.6857
# Epoch 13: val_loss improved from 0.67812 to 0.64301, saving model to Checkpoint_4.h5
# 20/20 [==============================] - 7s 347ms/step - loss: 0.6633 - accuracy: 0.6857 - val_loss: 0.6430 - val_accuracy: 0.6855
# Epoch 14/15
# 20/20 [==============================] - ETA: 0s - loss: 0.5691 - accuracy: 0.7626
# Epoch 14: val_loss improved from 0.64301 to 0.54504, saving model to Checkpoint_4.h5
# 20/20 [==============================] - 5s 276ms/step - loss: 0.5691 - accuracy: 0.7626 - val_loss: 0.5450 - val_accuracy: 0.7230
# Epoch 15/15
# 20/20 [==============================] - ETA: 0s - loss: 0.4266 - accuracy: 0.8195
# Epoch 15: val_loss improved from 0.54504 to 0.53398, saving model to Checkpoint_4.h5
# 20/20 [==============================] - 8s 400ms/step - loss: 0.4266 - accuracy: 0.8195 - val_loss: 0.5340 - val_accuracy: 0.7542
# 500/500 [==============================] - 7s 15ms/step - loss: 0.5174 - accuracy: 0.7596
# Accuracy on test data after iteration 4: 0.7596250176429749, Number of labeled samples: 4996
# 500/500 [==============================] - 9s 16ms/step
