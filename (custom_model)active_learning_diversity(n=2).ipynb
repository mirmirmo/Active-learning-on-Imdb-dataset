# %% [markdown]
# ## Importing necessary libraries

# %%
import tensorflow as tf
import numpy as np
import re, os
import matplotlib.pyplot as plt
import pandas as pd
import sklearn

# %% [markdown]
# ## Getting data from Kaggle

# %%
import requests
import pandas as pd
import tarfile
import os

# Define the URL for the IMDb sentiment analysis dataset
url = "https://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz"
dataset_filename = "aclImdb_v1.tar.gz"

# Specify the download location
download_location = "./data/"

# Create the download directory if it doesn't exist
if not os.path.exists(download_location):
    os.makedirs(download_location)

# Download the dataset
response = requests.get(url)
with open(download_location + dataset_filename, 'wb') as f:
    f.write(response.content)

# Extract the downloaded file
with tarfile.open(download_location + dataset_filename, 'r:gz') as tar:
    tar.extractall(download_location)

# Define the path to the extracted dataset
dataset_path = download_location + "aclImdb/"

# Function to load the dataset into a Pandas DataFrame
def load_imdb_dataset(data_path):
    texts = []
    labels = []
    for category in ['train', 'test']:
        for sentiment in ['pos', 'neg']:
            folder_path = os.path.join(data_path, category, sentiment)
            for filename in os.listdir(folder_path):
                with open(os.path.join(folder_path, filename), 'r', encoding='utf-8') as file:
                    text = file.read()
                    texts.append(text)
                    labels.append(1 if sentiment == 'pos' else 0)
    return pd.DataFrame({'text': texts, 'label': labels})

# Load the dataset into a Pandas DataFrame
imdb_df = load_imdb_dataset(dataset_path)

# Display the first few rows of the DataFrame
print(imdb_df.head())
# Out:
#                                                 text  label
# 0  I'm intrigued by the strong sense of favour to...      1
# 1  The best film on the battle of San Antonio, Te...      1
# 2  This is how i felt while watching this film. I...      1
# 3  While not as famous as some of their other col...      1
# 4  Unlike many other films, which are disturbing ...      1

# %%
len(imdb_df)
# Out:
# 50000

# %%
from sklearn.model_selection import train_test_split

# Split the dataset into train, test, and validation sets
df_train, test_val_df = train_test_split(imdb_df, test_size=20000, random_state=42)
df_test, df_val = train_test_split(test_val_df, test_size=0.2, random_state=42)

# Display the shapes of the resulting DataFrames
print("Train set shape:", df_train.shape)
print("Test set shape:", df_test.shape)
print("Validation set shape:", df_val.shape)
# Out:
# Train set shape: (30000, 2)
# Test set shape: (16000, 2)
# Validation set shape: (4000, 2)

# %%
df_val.head()
# Out:
#                                                     text  label
# 26891  The film is a remake of a 1956 BBC serial call...      1
# 25024  During World War II, two Byelorussian (Soviet ...      1
# 11666  The information contained in this movie is som...      1
# 40303  and I have seen a lot of films. I saw this in ...      0
# 18010  This su*k! Why do they have to make movies tha...      0

# %%
df_test.head()
# Out:
#                                                     text  label
# 24835  As usual, on IMDb, going by the majority vote ...      0
# 28073  Spoilers in this review! Despite a few highly ...      1
# 31069  I think this movie is the most misunderstood f...      1
# 25736  This film is excellent! Fear of watching docum...      1
# 40229  At the least some of the sitcoms that churn en...      0

# %%
df_train['label'].value_counts()
# Out:
# 0    15084
# 1    14916
# Name: label, dtype: int64

# %% [markdown]
# ## Preprocessing

# %%
# Cleaning/Preprocessing Helper function

def preprocess(s):
  s = re.sub(r'@[a-zA-Z0-9_.]+ ', '', str(s))
  s = re.sub(r'#[a-zA-Z0-9_.]+ ', '', str(s))
  s = re.sub(r'''[^a-zA-Z0-9?. ]+''', '', s)
  s = re.sub(r''''[' ']+''', " ", s)
  s = re.sub(r'(\w)\1{2,}',r'\1',s)
  s = s.lower().strip()
  return s

# %%
df_train['text'] = df_train['text'].apply(preprocess)
df_val['text'] = df_val['text'].apply(preprocess)
df_test['text'] = df_test['text'].apply(preprocess)

# %%
def get_data(df):
  zeros, ones = df[df['label']==0], df[df['label']==1]
  zero_text, zero_labels = zeros['text'].to_numpy(), zeros['label'].to_numpy()
  one_text, one_labels = ones['text'].to_numpy(), ones['label'].to_numpy()
  X, Y = np.concatenate((one_text,zero_text)), np.concatenate((one_labels,zero_labels))
  return X,Y

# %%
X_train,Y_train = get_data(df_train)
X_val,Y_val = get_data(df_val)
X_test,Y_test = get_data(df_test)

# %%
X_train.shape,X_val.shape,X_test.shape
# Out:
# ((30000,), (4000,), (16000,))

# %% [markdown]
# ## Creating the Model

# %%
# Instantiating the Tokenizer and creating sequences
tokenizer = tf.keras.preprocessing.text.Tokenizer(3000,oov_token=1)
tokenizer.fit_on_texts(X_train)
train_seq = tokenizer.texts_to_sequences(X_train)
val_seq = tokenizer.texts_to_sequences(X_val)
test_seq = tokenizer.texts_to_sequences(X_test)

# %%
# Padding all sequences
train_seq = tf.keras.preprocessing.sequence.pad_sequences(train_seq,maxlen=50,padding='post')
val_seq = tf.keras.preprocessing.sequence.pad_sequences(val_seq,maxlen=50,padding='post')
test_seq = tf.keras.preprocessing.sequence.pad_sequences(test_seq,maxlen=50,padding='post')

# %% [markdown]
# ## Creating the Model

# %%
# from tensorflow.keras.layers import Embedding,Dense,LSTM,Flatten,Dropout
# def create_model():
#   model = tf.keras.models.Sequential()
#   model.add(Embedding(3000,64))
#   model.add(LSTM(32))
#   model.add(Flatten())
#   model.add(Dense(64,activation='relu'))
#   model.add(Dropout(0.3))
#   model.add(Dense(32,activation='relu'))
#   model.add(Dropout(0.3))
#   model.add(Dense(4,activation='relu'))
#   model.add(Dense(1,activation='sigmoid'))
#   model.summary()
#   model.compile(optimizer=tf.keras.optimizers.Adam(0.0001),loss=tf.keras.losses.BinaryCrossentropy(),metrics=['accuracy'])
#   return model

# %%
import tensorflow as tf
from tensorflow.keras.layers import Embedding, LSTM, Conv1D, MaxPooling1D, Bidirectional, GlobalMaxPooling1D, Dense, Dropout

def create_model():
    model = tf.keras.models.Sequential()
    model.add(Embedding(input_dim=3000, output_dim=128))

    # Convolutional layers
    model.add(Conv1D(filters=128, kernel_size=3, activation='relu'))
    model.add(MaxPooling1D(pool_size=2))

    # Bidirectional LSTM layer
    model.add(Bidirectional(LSTM(units=64, return_sequences=True)))

    # Global Max Pooling layer
    model.add(GlobalMaxPooling1D())

    # Dense layers
    model.add(Dense(units=256, activation='relu'))
    model.add(Dropout(0.5))

    model.add(Dense(units=128, activation='relu'))
    model.add(Dropout(0.5))

    model.add(Dense(units=64, activation='relu'))
    model.add(Dropout(0.5))

    # Output layer
    model.add(Dense(units=1, activation='sigmoid'))

    model.summary()

    # Compile the model
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
                  loss=tf.keras.losses.BinaryCrossentropy(),
                  metrics=['accuracy'])

    return model

# %% [markdown]
# ## Full Model Training

# %%
# HELPER FUNCTION

def plot(history):
  plt.plot(history.history['loss'])
  plt.plot(history.history['val_loss'])
  plt.legend(['train_loss','val_loss'])
  plt.xlabel('Epochs')
  plt.ylabel('Loss')
  plt.show()

  plt.plot(history.history['accuracy'])
  plt.plot(history.history['val_accuracy'])
  plt.legend(['train_accuracy','val_accuracy'])
  plt.xlabel('Epochs')
  plt.ylabel('Accuracy')
  plt.show()

# %%
def train_full_model(train_seq,Y_train,val_seq,Y_val,test_seq,Y_test):
  model = create_model()
  history = model.fit(train_seq,Y_train,256,15,validation_data=(val_seq,Y_val),callbacks=[tf.keras.callbacks.ModelCheckpoint('FullModelCheckpoint.h5',save_best_only=True,verbose=1),tf.keras.callbacks.EarlyStopping(patience=6,verbose=1)])
  plot(history)
  model = tf.keras.models.load_model('FullModelCheckpoint.h5')
  print(model.evaluate(test_seq,Y_test))
  return model

# %% [markdown]
# ## Active Learning

# %%
# HELPER FUNCTIONS

def append_history(losses,val_losses,acc,val_acc,history):
  losses = losses + history.history['loss']
  val_losses = val_losses + history.history['val_loss']
  acc = acc + history.history['accuracy']
  val_acc = val_acc + history.history['val_accuracy']
  return losses,val_losses,acc,val_acc

def plot_merged_metrics(losses,val_losses,accuracies,val_accuracies):
  plt.plot(losses)
  plt.plot(val_losses)
  plt.legend(['train_loss','val_loss'])
  plt.xlabel('Epochs')
  plt.ylabel('Loss')
  plt.show()

  plt.plot(accuracies)
  plt.plot(val_accuracies)
  plt.legend(['train_accuracy','val_accuracy'])
  plt.xlabel('Epochs')
  plt.ylabel('Accuracy')
  plt.show()

# %%
import numpy as np
import tensorflow as tf
from sklearn.cluster import KMeans

# Set a random seed for reproducibility
np.random.seed(42)
tf.random.set_seed(42)

def diversity_sampling(model, pool_features, pool_labels, sampling_size=2000, num_clusters=2):
    # Get the penultimate layer activations as features for diversity calculation
    penultimate_layer_model = tf.keras.Model(inputs=model.input, outputs=model.layers[-2].output)
    features = penultimate_layer_model.predict(pool_features)

    # Apply k-means clustering to the penultimate layer features
    kmeans = KMeans(n_clusters=num_clusters, random_state=42)
    cluster_assignments = kmeans.fit_predict(features)

    # Calculate the diversity scores for each sample in the pool
    diversity_scores = []
    for i in range(pool_features.shape[0]):
        cluster_distance = np.min(np.linalg.norm(features[i] - kmeans.cluster_centers_, axis=1))
        diversity_scores.append(cluster_distance)

    # Select samples with high diversity
    sample_indices = np.argsort(diversity_scores)[-sampling_size:]

    # Convert sample_indices to an array of integers
    sample_indices = np.array(sample_indices, dtype=np.int32)

    # Use boolean indexing to get the selected labels
    selected_labels = pool_labels[sample_indices]
    selected_samples = pool_features[sample_indices]

    return selected_samples, selected_labels


def train_small_models(train_features, train_labels, pool_features, pool_labels, val_seq, Y_val, test_seq, Y_test, iters=3, sampling_size=2000):
    losses, val_losses, accuracies, val_accuracies = [], [], [], []

    for iter_n in range(iters):
        # Create a new model for each iteration
        model = create_model()
        model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

        checkpoint = tf.keras.callbacks.ModelCheckpoint(f'Checkpoint_{iter_n}.h5', save_best_only=True, verbose=1)

        print(f"Starting to train with {train_features.shape[0]} labeled samples")

        history = model.fit(train_features, train_labels, batch_size=256, epochs=15,
                            validation_data=(val_seq, Y_val),
                            callbacks=[checkpoint],
                            shuffle=True)  # Ensure training data shuffling for randomness

        losses, val_losses, accuracies, val_accuracies = append_history(losses, val_losses, accuracies, val_accuracies, history)

        # Evaluate and print accuracy on test data
        test_accuracy = model.evaluate(test_seq, Y_test)[1]
        print(f"Accuracy on test data after iteration {iter_n}: {test_accuracy}, Number of labeled samples: {train_features.shape[0]}")

        # Use diversity sampling to select samples from the pool
        selected_samples, selected_labels = diversity_sampling(model, pool_features, pool_labels, sampling_size)

        # Remove the chosen samples from the pool
        pool_features = np.delete(pool_features, selected_samples, axis=0)
        pool_labels = np.delete(pool_labels, selected_samples)

        # Add the sampled entries to the original data
        train_features = np.vstack((train_features, selected_samples))
        train_labels = np.hstack((train_labels, selected_labels))

    plot_merged_metrics(losses, val_losses, accuracies, val_accuracies)

    return model

# %% [markdown]
# ## Ensembling

# %%
# # Splitting Data into Oracle Set(Unlabelled set) and Original Training set
import sklearn.model_selection
train_features,pool_features,train_labels,pool_labels = sklearn.model_selection.train_test_split(train_seq,Y_train,test_size=29000,stratify=Y_train)
train_features.shape,pool_features.shape
# Out:
# ((1000, 50), (29000, 50))

# %%
# Training 3 Active Learning Models for Ensembling
al_model1 = train_small_models(train_features,train_labels,pool_features,pool_labels,val_seq,Y_val,test_seq,Y_test,iters=5, sampling_size=1000)
# al_model2 = train_small_models(train_features,train_labels,pool_features,pool_labels,val_seq,Y_val,test_seq,Y_test)
# al_model3 = train_small_models(train_features,train_labels,pool_features,pool_labels,val_seq,Y_val,test_seq,Y_test)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, None, 128)         384000
#
#  conv1d (Conv1D)             (None, None, 128)         49280
#
#  max_pooling1d (MaxPooling1  (None, None, 128)         0
#  D)
#
#  bidirectional (Bidirection  (None, None, 128)         98816
#  al)
#
#  global_max_pooling1d (Glob  (None, 128)               0
#  alMaxPooling1D)
#
#  dense (Dense)               (None, 256)               33024
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 64)                8256
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 606337 (2.31 MB)
# Trainable params: 606337 (2.31 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Starting to train with 1000 labeled samples
# Epoch 1/15
# 4/4 [==============================] - ETA: 0s - loss: 0.6935 - accuracy: 0.5020
# Epoch 1: val_loss improved from inf to 0.69313, saving model to Checkpoint_0.h5
# 4/4 [==============================] - 9s 886ms/step - loss: 0.6935 - accuracy: 0.5020 - val_loss: 0.6931 - val_accuracy: 0.5125
# Epoch 2/15
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 4/4 [==============================] - ETA: 0s - loss: 0.6934 - accuracy: 0.5160
# Epoch 2: val_loss improved from 0.69313 to 0.69302, saving model to Checkpoint_0.h5
# 4/4 [==============================] - 2s 671ms/step - loss: 0.6934 - accuracy: 0.5160 - val_loss: 0.6930 - val_accuracy: 0.5293
# Epoch 3/15
# 4/4 [==============================] - ETA: 0s - loss: 0.6938 - accuracy: 0.4860
# Epoch 3: val_loss did not improve from 0.69302
# 4/4 [==============================] - 2s 609ms/step - loss: 0.6938 - accuracy: 0.4860 - val_loss: 0.6932 - val_accuracy: 0.4868
# Epoch 4/15
# 4/4 [==============================] - ETA: 0s - loss: 0.6934 - accuracy: 0.5170
# Epoch 4: val_loss did not improve from 0.69302
# 4/4 [==============================] - 3s 849ms/step - loss: 0.6934 - accuracy: 0.5170 - val_loss: 0.6932 - val_accuracy: 0.4868
# Epoch 5/15
# 4/4 [==============================] - ETA: 0s - loss: 0.6924 - accuracy: 0.5070
# Epoch 5: val_loss improved from 0.69302 to 0.69279, saving model to Checkpoint_0.h5
# 4/4 [==============================] - 2s 564ms/step - loss: 0.6924 - accuracy: 0.5070 - val_loss: 0.6928 - val_accuracy: 0.5370
# Epoch 6/15
# 4/4 [==============================] - ETA: 0s - loss: 0.6928 - accuracy: 0.5060
# Epoch 6: val_loss did not improve from 0.69279
# 4/4 [==============================] - 2s 656ms/step - loss: 0.6928 - accuracy: 0.5060 - val_loss: 0.6929 - val_accuracy: 0.4913
# Epoch 7/15
# 4/4 [==============================] - ETA: 0s - loss: 0.6905 - accuracy: 0.5150
# Epoch 7: val_loss improved from 0.69279 to 0.69193, saving model to Checkpoint_0.h5
# 4/4 [==============================] - 2s 644ms/step - loss: 0.6905 - accuracy: 0.5150 - val_loss: 0.6919 - val_accuracy: 0.5500
# Epoch 8/15
# 4/4 [==============================] - ETA: 0s - loss: 0.6888 - accuracy: 0.5800
# Epoch 8: val_loss improved from 0.69193 to 0.69027, saving model to Checkpoint_0.h5
# 4/4 [==============================] - 2s 641ms/step - loss: 0.6888 - accuracy: 0.5800 - val_loss: 0.6903 - val_accuracy: 0.5905
# Epoch 9/15
# 4/4 [==============================] - ETA: 0s - loss: 0.6841 - accuracy: 0.6110
# Epoch 9: val_loss improved from 0.69027 to 0.68686, saving model to Checkpoint_0.h5
# 4/4 [==============================] - 3s 1s/step - loss: 0.6841 - accuracy: 0.6110 - val_loss: 0.6869 - val_accuracy: 0.5680
# Epoch 10/15
# 4/4 [==============================] - ETA: 0s - loss: 0.6726 - accuracy: 0.6370
# Epoch 10: val_loss improved from 0.68686 to 0.67422, saving model to Checkpoint_0.h5
# 4/4 [==============================] - 2s 652ms/step - loss: 0.6726 - accuracy: 0.6370 - val_loss: 0.6742 - val_accuracy: 0.6225
# Epoch 11/15
# 4/4 [==============================] - ETA: 0s - loss: 0.6338 - accuracy: 0.7440
# Epoch 11: val_loss improved from 0.67422 to 0.64441, saving model to Checkpoint_0.h5
# 4/4 [==============================] - 2s 597ms/step - loss: 0.6338 - accuracy: 0.7440 - val_loss: 0.6444 - val_accuracy: 0.6345
# Epoch 12/15
# 4/4 [==============================] - ETA: 0s - loss: 0.5127 - accuracy: 0.8300
# Epoch 12: val_loss improved from 0.64441 to 0.59736, saving model to Checkpoint_0.h5
# 4/4 [==============================] - 2s 652ms/step - loss: 0.5127 - accuracy: 0.8300 - val_loss: 0.5974 - val_accuracy: 0.6817
# Epoch 13/15
# 4/4 [==============================] - ETA: 0s - loss: 0.3078 - accuracy: 0.9030
# Epoch 13: val_loss did not improve from 0.59736
# 4/4 [==============================] - 2s 652ms/step - loss: 0.3078 - accuracy: 0.9030 - val_loss: 0.8327 - val_accuracy: 0.6950
# Epoch 14/15
# 4/4 [==============================] - ETA: 0s - loss: 0.2141 - accuracy: 0.9330
# Epoch 14: val_loss did not improve from 0.59736
# 4/4 [==============================] - 3s 1s/step - loss: 0.2141 - accuracy: 0.9330 - val_loss: 1.3039 - val_accuracy: 0.6697
# Epoch 15/15
# 4/4 [==============================] - ETA: 0s - loss: 0.1644 - accuracy: 0.9480
# Epoch 15: val_loss did not improve from 0.59736
# 4/4 [==============================] - 2s 649ms/step - loss: 0.1644 - accuracy: 0.9480 - val_loss: 1.5910 - val_accuracy: 0.6340
# 500/500 [==============================] - 8s 15ms/step - loss: 1.5037 - accuracy: 0.6529
# Accuracy on test data after iteration 0: 0.6528750061988831, Number of labeled samples: 1000
# 907/907 [==============================] - 14s 15ms/step
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, None, 128)         384000
#
#  conv1d_1 (Conv1D)           (None, None, 128)         49280
#
#  max_pooling1d_1 (MaxPoolin  (None, None, 128)         0
#  g1D)
#
#  bidirectional_1 (Bidirecti  (None, None, 128)         98816
#  onal)
#
#  global_max_pooling1d_1 (Gl  (None, 128)               0
#  obalMaxPooling1D)
#
#  dense_4 (Dense)             (None, 256)               33024
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_5 (Dense)             (None, 128)               32896
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  dense_6 (Dense)             (None, 64)                8256
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_7 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 606337 (2.31 MB)
# Trainable params: 606337 (2.31 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Starting to train with 2000 labeled samples
# Epoch 1/15
# 8/8 [==============================] - ETA: 0s - loss: 0.6895 - accuracy: 0.5585
# Epoch 1: val_loss improved from inf to 0.70018, saving model to Checkpoint_1.h5
# 8/8 [==============================] - 10s 601ms/step - loss: 0.6895 - accuracy: 0.5585 - val_loss: 0.7002 - val_accuracy: 0.5132
# Epoch 2/15
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 8/8 [==============================] - ETA: 0s - loss: 0.6796 - accuracy: 0.5660
# Epoch 2: val_loss improved from 0.70018 to 0.69383, saving model to Checkpoint_1.h5
# 8/8 [==============================] - 3s 414ms/step - loss: 0.6796 - accuracy: 0.5660 - val_loss: 0.6938 - val_accuracy: 0.5132
# Epoch 3/15
# 8/8 [==============================] - ETA: 0s - loss: 0.6599 - accuracy: 0.5645
# Epoch 3: val_loss improved from 0.69383 to 0.69302, saving model to Checkpoint_1.h5
# 8/8 [==============================] - 3s 421ms/step - loss: 0.6599 - accuracy: 0.5645 - val_loss: 0.6930 - val_accuracy: 0.5132
# Epoch 4/15
# 8/8 [==============================] - ETA: 0s - loss: 0.5686 - accuracy: 0.6290
# Epoch 4: val_loss did not improve from 0.69302
# 8/8 [==============================] - 5s 731ms/step - loss: 0.5686 - accuracy: 0.6290 - val_loss: 0.7166 - val_accuracy: 0.6555
# Epoch 5/15
# 8/8 [==============================] - ETA: 0s - loss: 0.4527 - accuracy: 0.8355
# Epoch 5: val_loss improved from 0.69302 to 0.61657, saving model to Checkpoint_1.h5
# 8/8 [==============================] - 3s 395ms/step - loss: 0.4527 - accuracy: 0.8355 - val_loss: 0.6166 - val_accuracy: 0.6388
# Epoch 6/15
# 8/8 [==============================] - ETA: 0s - loss: 0.2947 - accuracy: 0.9085
# Epoch 6: val_loss did not improve from 0.61657
# 8/8 [==============================] - 3s 395ms/step - loss: 0.2947 - accuracy: 0.9085 - val_loss: 0.6858 - val_accuracy: 0.7055
# Epoch 7/15
# 8/8 [==============================] - ETA: 0s - loss: 0.1679 - accuracy: 0.9480
# Epoch 7: val_loss did not improve from 0.61657
# 8/8 [==============================] - 5s 665ms/step - loss: 0.1679 - accuracy: 0.9480 - val_loss: 0.8486 - val_accuracy: 0.7092
# Epoch 8/15
# 8/8 [==============================] - ETA: 0s - loss: 0.1230 - accuracy: 0.9640
# Epoch 8: val_loss did not improve from 0.61657
# 8/8 [==============================] - 3s 369ms/step - loss: 0.1230 - accuracy: 0.9640 - val_loss: 0.8969 - val_accuracy: 0.7053
# Epoch 9/15
# 8/8 [==============================] - ETA: 0s - loss: 0.0876 - accuracy: 0.9765
# Epoch 9: val_loss did not improve from 0.61657
# 8/8 [==============================] - 3s 408ms/step - loss: 0.0876 - accuracy: 0.9765 - val_loss: 0.9274 - val_accuracy: 0.7185
# Epoch 10/15
# 8/8 [==============================] - ETA: 0s - loss: 0.0462 - accuracy: 0.9880
# Epoch 10: val_loss did not improve from 0.61657
# 8/8 [==============================] - 3s 390ms/step - loss: 0.0462 - accuracy: 0.9880 - val_loss: 1.2436 - val_accuracy: 0.7107
# Epoch 11/15
# 8/8 [==============================] - ETA: 0s - loss: 0.0256 - accuracy: 0.9955
# Epoch 11: val_loss did not improve from 0.61657
# 8/8 [==============================] - 4s 577ms/step - loss: 0.0256 - accuracy: 0.9955 - val_loss: 1.7730 - val_accuracy: 0.6973
# Epoch 12/15
# 8/8 [==============================] - ETA: 0s - loss: 0.0092 - accuracy: 0.9965
# Epoch 12: val_loss did not improve from 0.61657
# 8/8 [==============================] - 3s 391ms/step - loss: 0.0092 - accuracy: 0.9965 - val_loss: 1.7791 - val_accuracy: 0.7100
# Epoch 13/15
# 8/8 [==============================] - ETA: 0s - loss: 0.0051 - accuracy: 0.9995
# Epoch 13: val_loss did not improve from 0.61657
# 8/8 [==============================] - 3s 406ms/step - loss: 0.0051 - accuracy: 0.9995 - val_loss: 2.0459 - val_accuracy: 0.6982
# Epoch 14/15
# 8/8 [==============================] - ETA: 0s - loss: 0.0042 - accuracy: 0.9990
# Epoch 14: val_loss did not improve from 0.61657
# 8/8 [==============================] - 3s 402ms/step - loss: 0.0042 - accuracy: 0.9990 - val_loss: 2.0001 - val_accuracy: 0.7055
# Epoch 15/15
# 8/8 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 1.0000
# Epoch 15: val_loss did not improve from 0.61657
# 8/8 [==============================] - 4s 521ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 2.1896 - val_accuracy: 0.7038
# 500/500 [==============================] - 8s 16ms/step - loss: 2.1332 - accuracy: 0.7126
# Accuracy on test data after iteration 1: 0.7125625014305115, Number of labeled samples: 2000
# 825/825 [==============================] - 13s 15ms/step
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, None, 128)         384000
#
#  conv1d_2 (Conv1D)           (None, None, 128)         49280
#
#  max_pooling1d_2 (MaxPoolin  (None, None, 128)         0
#  g1D)
#
#  bidirectional_2 (Bidirecti  (None, None, 128)         98816
#  onal)
#
#  global_max_pooling1d_2 (Gl  (None, 128)               0
#  obalMaxPooling1D)
#
#  dense_8 (Dense)             (None, 256)               33024
#
#  dropout_6 (Dropout)         (None, 256)               0
#
#  dense_9 (Dense)             (None, 128)               32896
#
#  dropout_7 (Dropout)         (None, 128)               0
#
#  dense_10 (Dense)            (None, 64)                8256
#
#  dropout_8 (Dropout)         (None, 64)                0
#
#  dense_11 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 606337 (2.31 MB)
# Trainable params: 606337 (2.31 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Starting to train with 3000 labeled samples
# Epoch 1/15
# 12/12 [==============================] - ETA: 0s - loss: 0.6922 - accuracy: 0.5167
# Epoch 1: val_loss improved from inf to 0.69252, saving model to Checkpoint_2.h5
# 12/12 [==============================] - 11s 512ms/step - loss: 0.6922 - accuracy: 0.5167 - val_loss: 0.6925 - val_accuracy: 0.5132
# Epoch 2/15
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 12/12 [==============================] - ETA: 0s - loss: 0.6805 - accuracy: 0.5353
# Epoch 2: val_loss improved from 0.69252 to 0.68192, saving model to Checkpoint_2.h5
# 12/12 [==============================] - 4s 321ms/step - loss: 0.6805 - accuracy: 0.5353 - val_loss: 0.6819 - val_accuracy: 0.5332
# Epoch 3/15
# 12/12 [==============================] - ETA: 0s - loss: 0.5307 - accuracy: 0.7847
# Epoch 3: val_loss did not improve from 0.68192
# 12/12 [==============================] - 4s 319ms/step - loss: 0.5307 - accuracy: 0.7847 - val_loss: 0.6904 - val_accuracy: 0.6722
# Epoch 4/15
# 12/12 [==============================] - ETA: 0s - loss: 0.3050 - accuracy: 0.9010
# Epoch 4: val_loss did not improve from 0.68192
# 12/12 [==============================] - 5s 401ms/step - loss: 0.3050 - accuracy: 0.9010 - val_loss: 0.7502 - val_accuracy: 0.6902
# Epoch 5/15
# 12/12 [==============================] - ETA: 0s - loss: 0.1926 - accuracy: 0.9403
# Epoch 5: val_loss did not improve from 0.68192
# 12/12 [==============================] - 6s 482ms/step - loss: 0.1926 - accuracy: 0.9403 - val_loss: 0.6825 - val_accuracy: 0.7220
# Epoch 6/15
# 12/12 [==============================] - ETA: 0s - loss: 0.1035 - accuracy: 0.9713
# Epoch 6: val_loss did not improve from 0.68192
# 12/12 [==============================] - 4s 318ms/step - loss: 0.1035 - accuracy: 0.9713 - val_loss: 0.9366 - val_accuracy: 0.7247
# Epoch 7/15
# 12/12 [==============================] - ETA: 0s - loss: 0.0469 - accuracy: 0.9870
# Epoch 7: val_loss did not improve from 0.68192
# 12/12 [==============================] - 5s 404ms/step - loss: 0.0469 - accuracy: 0.9870 - val_loss: 1.1562 - val_accuracy: 0.7165
# Epoch 8/15
# 12/12 [==============================] - ETA: 0s - loss: 0.0248 - accuracy: 0.9943
# Epoch 8: val_loss did not improve from 0.68192
# 12/12 [==============================] - 4s 329ms/step - loss: 0.0248 - accuracy: 0.9943 - val_loss: 1.4355 - val_accuracy: 0.7172
# Epoch 9/15
# 12/12 [==============================] - ETA: 0s - loss: 0.0103 - accuracy: 0.9977
# Epoch 9: val_loss did not improve from 0.68192
# 12/12 [==============================] - 3s 290ms/step - loss: 0.0103 - accuracy: 0.9977 - val_loss: 2.1313 - val_accuracy: 0.7048
# Epoch 10/15
# 12/12 [==============================] - ETA: 0s - loss: 0.0059 - accuracy: 0.9983
# Epoch 10: val_loss did not improve from 0.68192
# 12/12 [==============================] - 5s 435ms/step - loss: 0.0059 - accuracy: 0.9983 - val_loss: 1.8810 - val_accuracy: 0.7057
# Epoch 11/15
# 12/12 [==============================] - ETA: 0s - loss: 0.0065 - accuracy: 0.9980
# Epoch 11: val_loss did not improve from 0.68192
# 12/12 [==============================] - 4s 308ms/step - loss: 0.0065 - accuracy: 0.9980 - val_loss: 2.6947 - val_accuracy: 0.6925
# Epoch 12/15
# 12/12 [==============================] - ETA: 0s - loss: 0.0091 - accuracy: 0.9977
# Epoch 12: val_loss did not improve from 0.68192
# 12/12 [==============================] - 4s 334ms/step - loss: 0.0091 - accuracy: 0.9977 - val_loss: 2.3448 - val_accuracy: 0.7023
# Epoch 13/15
# 12/12 [==============================] - ETA: 0s - loss: 0.0105 - accuracy: 0.9957
# Epoch 13: val_loss did not improve from 0.68192
# 12/12 [==============================] - 4s 389ms/step - loss: 0.0105 - accuracy: 0.9957 - val_loss: 2.2108 - val_accuracy: 0.6970
# Epoch 14/15
# 12/12 [==============================] - ETA: 0s - loss: 0.0140 - accuracy: 0.9953
# Epoch 14: val_loss did not improve from 0.68192
# 12/12 [==============================] - 4s 329ms/step - loss: 0.0140 - accuracy: 0.9953 - val_loss: 2.1982 - val_accuracy: 0.7092
# Epoch 15/15
# 12/12 [==============================] - ETA: 0s - loss: 0.0034 - accuracy: 0.9987
# Epoch 15: val_loss did not improve from 0.68192
# 12/12 [==============================] - 4s 323ms/step - loss: 0.0034 - accuracy: 0.9987 - val_loss: 2.3381 - val_accuracy: 0.7050
# 500/500 [==============================] - 7s 13ms/step - loss: 2.3404 - accuracy: 0.7108
# Accuracy on test data after iteration 2: 0.710812509059906, Number of labeled samples: 3000
# 743/743 [==============================] - 12s 14ms/step
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_3 (Embedding)     (None, None, 128)         384000
#
#  conv1d_3 (Conv1D)           (None, None, 128)         49280
#
#  max_pooling1d_3 (MaxPoolin  (None, None, 128)         0
#  g1D)
#
#  bidirectional_3 (Bidirecti  (None, None, 128)         98816
#  onal)
#
#  global_max_pooling1d_3 (Gl  (None, 128)               0
#  obalMaxPooling1D)
#
#  dense_12 (Dense)            (None, 256)               33024
#
#  dropout_9 (Dropout)         (None, 256)               0
#
#  dense_13 (Dense)            (None, 128)               32896
#
#  dropout_10 (Dropout)        (None, 128)               0
#
#  dense_14 (Dense)            (None, 64)                8256
#
#  dropout_11 (Dropout)        (None, 64)                0
#
#  dense_15 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 606337 (2.31 MB)
# Trainable params: 606337 (2.31 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Starting to train with 4000 labeled samples
# Epoch 1/15
# 16/16 [==============================] - ETA: 0s - loss: 0.6921 - accuracy: 0.5180
# Epoch 1: val_loss improved from inf to 0.69283, saving model to Checkpoint_3.h5
# 16/16 [==============================] - 11s 364ms/step - loss: 0.6921 - accuracy: 0.5180 - val_loss: 0.6928 - val_accuracy: 0.4868
# Epoch 2/15
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 16/16 [==============================] - ETA: 0s - loss: 0.6390 - accuracy: 0.6737
# Epoch 2: val_loss improved from 0.69283 to 0.63650, saving model to Checkpoint_3.h5
# 16/16 [==============================] - 6s 353ms/step - loss: 0.6390 - accuracy: 0.6737 - val_loss: 0.6365 - val_accuracy: 0.6467
# Epoch 3/15
# 16/16 [==============================] - ETA: 0s - loss: 0.2964 - accuracy: 0.9030
# Epoch 3: val_loss improved from 0.63650 to 0.55655, saving model to Checkpoint_3.h5
# 16/16 [==============================] - 4s 269ms/step - loss: 0.2964 - accuracy: 0.9030 - val_loss: 0.5565 - val_accuracy: 0.7427
# Epoch 4/15
# 16/16 [==============================] - ETA: 0s - loss: 0.1668 - accuracy: 0.9515
# Epoch 4: val_loss did not improve from 0.55655
# 16/16 [==============================] - 7s 422ms/step - loss: 0.1668 - accuracy: 0.9515 - val_loss: 0.7414 - val_accuracy: 0.7270
# Epoch 5/15
# 16/16 [==============================] - ETA: 0s - loss: 0.1125 - accuracy: 0.9657
# Epoch 5: val_loss did not improve from 0.55655
# 16/16 [==============================] - 5s 305ms/step - loss: 0.1125 - accuracy: 0.9657 - val_loss: 0.8050 - val_accuracy: 0.7155
# Epoch 6/15
# 16/16 [==============================] - ETA: 0s - loss: 0.0767 - accuracy: 0.9775
# Epoch 6: val_loss did not improve from 0.55655
# 16/16 [==============================] - 5s 299ms/step - loss: 0.0767 - accuracy: 0.9775 - val_loss: 1.0193 - val_accuracy: 0.7078
# Epoch 7/15
# 16/16 [==============================] - ETA: 0s - loss: 0.0378 - accuracy: 0.9893
# Epoch 7: val_loss did not improve from 0.55655
# 16/16 [==============================] - 6s 359ms/step - loss: 0.0378 - accuracy: 0.9893 - val_loss: 1.2095 - val_accuracy: 0.7097
# Epoch 8/15
# 16/16 [==============================] - ETA: 0s - loss: 0.0213 - accuracy: 0.9937
# Epoch 8: val_loss did not improve from 0.55655
# 16/16 [==============================] - 5s 294ms/step - loss: 0.0213 - accuracy: 0.9937 - val_loss: 1.6268 - val_accuracy: 0.7117
# Epoch 9/15
# 16/16 [==============================] - ETA: 0s - loss: 0.0153 - accuracy: 0.9945
# Epoch 9: val_loss did not improve from 0.55655
# 16/16 [==============================] - 6s 385ms/step - loss: 0.0153 - accuracy: 0.9945 - val_loss: 1.5489 - val_accuracy: 0.7157
# Epoch 10/15
# 16/16 [==============================] - ETA: 0s - loss: 0.0077 - accuracy: 0.9987
# Epoch 10: val_loss did not improve from 0.55655
# 16/16 [==============================] - 5s 302ms/step - loss: 0.0077 - accuracy: 0.9987 - val_loss: 1.8933 - val_accuracy: 0.7100
# Epoch 11/15
# 16/16 [==============================] - ETA: 0s - loss: 0.0031 - accuracy: 0.9995
# Epoch 11: val_loss did not improve from 0.55655
# 16/16 [==============================] - 5s 302ms/step - loss: 0.0031 - accuracy: 0.9995 - val_loss: 2.4405 - val_accuracy: 0.7140
# Epoch 12/15
# 16/16 [==============================] - ETA: 0s - loss: 0.0015 - accuracy: 0.9995
# Epoch 12: val_loss did not improve from 0.55655
# 16/16 [==============================] - 6s 355ms/step - loss: 0.0015 - accuracy: 0.9995 - val_loss: 2.5671 - val_accuracy: 0.7103
# Epoch 13/15
# 16/16 [==============================] - ETA: 0s - loss: 0.0029 - accuracy: 0.9990
# Epoch 13: val_loss did not improve from 0.55655
# 16/16 [==============================] - 5s 299ms/step - loss: 0.0029 - accuracy: 0.9990 - val_loss: 2.9493 - val_accuracy: 0.7115
# Epoch 14/15
# 16/16 [==============================] - ETA: 0s - loss: 0.0416 - accuracy: 0.9910
# Epoch 14: val_loss did not improve from 0.55655
# 16/16 [==============================] - 5s 350ms/step - loss: 0.0416 - accuracy: 0.9910 - val_loss: 1.3781 - val_accuracy: 0.6977
# Epoch 15/15
# 16/16 [==============================] - ETA: 0s - loss: 0.0223 - accuracy: 0.9937
# Epoch 15: val_loss did not improve from 0.55655
# 16/16 [==============================] - 4s 286ms/step - loss: 0.0223 - accuracy: 0.9937 - val_loss: 1.3184 - val_accuracy: 0.7085
# 500/500 [==============================] - 8s 16ms/step - loss: 1.3413 - accuracy: 0.7045
# Accuracy on test data after iteration 3: 0.7045000195503235, Number of labeled samples: 4000
# 662/662 [==============================] - 11s 15ms/step
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_4 (Embedding)     (None, None, 128)         384000
#
#  conv1d_4 (Conv1D)           (None, None, 128)         49280
#
#  max_pooling1d_4 (MaxPoolin  (None, None, 128)         0
#  g1D)
#
#  bidirectional_4 (Bidirecti  (None, None, 128)         98816
#  onal)
#
#  global_max_pooling1d_4 (Gl  (None, 128)               0
#  obalMaxPooling1D)
#
#  dense_16 (Dense)            (None, 256)               33024
#
#  dropout_12 (Dropout)        (None, 256)               0
#
#  dense_17 (Dense)            (None, 128)               32896
#
#  dropout_13 (Dropout)        (None, 128)               0
#
#  dense_18 (Dense)            (None, 64)                8256
#
#  dropout_14 (Dropout)        (None, 64)                0
#
#  dense_19 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 606337 (2.31 MB)
# Trainable params: 606337 (2.31 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Starting to train with 5000 labeled samples
# Epoch 1/15
# 20/20 [==============================] - ETA: 0s - loss: 0.6905 - accuracy: 0.5336
# Epoch 1: val_loss improved from inf to 0.69714, saving model to Checkpoint_4.h5
# 20/20 [==============================] - 13s 319ms/step - loss: 0.6905 - accuracy: 0.5336 - val_loss: 0.6971 - val_accuracy: 0.4868
# Epoch 2/15
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 20/20 [==============================] - ETA: 0s - loss: 0.5445 - accuracy: 0.6894
# Epoch 2: val_loss did not improve from 0.69714
# 20/20 [==============================] - 6s 324ms/step - loss: 0.5445 - accuracy: 0.6894 - val_loss: 0.7645 - val_accuracy: 0.7092
# Epoch 3/15
# 20/20 [==============================] - ETA: 0s - loss: 0.2225 - accuracy: 0.9308
# Epoch 3: val_loss improved from 0.69714 to 0.52810, saving model to Checkpoint_4.h5
# 20/20 [==============================] - 6s 289ms/step - loss: 0.2225 - accuracy: 0.9308 - val_loss: 0.5281 - val_accuracy: 0.7517
# Epoch 4/15
# 20/20 [==============================] - ETA: 0s - loss: 0.1335 - accuracy: 0.9582
# Epoch 4: val_loss did not improve from 0.52810
# 20/20 [==============================] - 5s 270ms/step - loss: 0.1335 - accuracy: 0.9582 - val_loss: 0.6047 - val_accuracy: 0.7445
# Epoch 5/15
# 20/20 [==============================] - ETA: 0s - loss: 0.0802 - accuracy: 0.9764
# Epoch 5: val_loss did not improve from 0.52810
# 20/20 [==============================] - 8s 377ms/step - loss: 0.0802 - accuracy: 0.9764 - val_loss: 0.8570 - val_accuracy: 0.7325
# Epoch 6/15
# 20/20 [==============================] - ETA: 0s - loss: 0.0537 - accuracy: 0.9842
# Epoch 6: val_loss did not improve from 0.52810
# 20/20 [==============================] - 5s 274ms/step - loss: 0.0537 - accuracy: 0.9842 - val_loss: 0.8896 - val_accuracy: 0.7345
# Epoch 7/15
# 20/20 [==============================] - ETA: 0s - loss: 0.0352 - accuracy: 0.9878
# Epoch 7: val_loss did not improve from 0.52810
# 20/20 [==============================] - 6s 319ms/step - loss: 0.0352 - accuracy: 0.9878 - val_loss: 1.3031 - val_accuracy: 0.7260
# Epoch 8/15
# 20/20 [==============================] - ETA: 0s - loss: 0.0172 - accuracy: 0.9950
# Epoch 8: val_loss did not improve from 0.52810
# 20/20 [==============================] - 5s 264ms/step - loss: 0.0172 - accuracy: 0.9950 - val_loss: 1.4852 - val_accuracy: 0.7185
# Epoch 9/15
# 20/20 [==============================] - ETA: 0s - loss: 0.0103 - accuracy: 0.9976
# Epoch 9: val_loss did not improve from 0.52810
# 20/20 [==============================] - 6s 329ms/step - loss: 0.0103 - accuracy: 0.9976 - val_loss: 1.6913 - val_accuracy: 0.7163
# Epoch 10/15
# 20/20 [==============================] - ETA: 0s - loss: 0.0075 - accuracy: 0.9976
# Epoch 10: val_loss did not improve from 0.52810
# 20/20 [==============================] - 6s 279ms/step - loss: 0.0075 - accuracy: 0.9976 - val_loss: 1.8469 - val_accuracy: 0.7063
# Epoch 11/15
# 20/20 [==============================] - ETA: 0s - loss: 0.0082 - accuracy: 0.9970
# Epoch 11: val_loss did not improve from 0.52810
# 20/20 [==============================] - 6s 329ms/step - loss: 0.0082 - accuracy: 0.9970 - val_loss: 1.9594 - val_accuracy: 0.7030
# Epoch 12/15
# 20/20 [==============================] - ETA: 0s - loss: 0.0060 - accuracy: 0.9982
# Epoch 12: val_loss did not improve from 0.52810
# 20/20 [==============================] - 6s 281ms/step - loss: 0.0060 - accuracy: 0.9982 - val_loss: 1.8018 - val_accuracy: 0.7107
# Epoch 13/15
# 20/20 [==============================] - ETA: 0s - loss: 0.0090 - accuracy: 0.9974
# Epoch 13: val_loss did not improve from 0.52810
# 20/20 [==============================] - 7s 332ms/step - loss: 0.0090 - accuracy: 0.9974 - val_loss: 2.1753 - val_accuracy: 0.7035
# Epoch 14/15
# 20/20 [==============================] - ETA: 0s - loss: 0.0085 - accuracy: 0.9970
# Epoch 14: val_loss did not improve from 0.52810
# 20/20 [==============================] - 5s 274ms/step - loss: 0.0085 - accuracy: 0.9970 - val_loss: 2.1082 - val_accuracy: 0.7042
# Epoch 15/15
# 20/20 [==============================] - ETA: 0s - loss: 0.0158 - accuracy: 0.9940
# Epoch 15: val_loss did not improve from 0.52810
# 20/20 [==============================] - 7s 334ms/step - loss: 0.0158 - accuracy: 0.9940 - val_loss: 1.7591 - val_accuracy: 0.7053
# 500/500 [==============================] - 9s 17ms/step - loss: 1.7586 - accuracy: 0.7046
# Accuracy on test data after iteration 4: 0.7045624852180481, Number of labeled samples: 5000
# 582/582 [==============================] - 10s 16ms/step
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
