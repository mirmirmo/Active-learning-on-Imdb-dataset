# %% [markdown]
# ## Importing necessary libraries

# %%
import tensorflow as tf
import numpy as np
import re, os
import matplotlib.pyplot as plt
import pandas as pd
import sklearn

# %% [markdown]
# ## Getting data from Kaggle

# %%
import requests
import pandas as pd
import tarfile
import os

# Define the URL for the IMDb sentiment analysis dataset
url = "https://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz"
dataset_filename = "aclImdb_v1.tar.gz"

# Specify the download location
download_location = "./data/"

# Create the download directory if it doesn't exist
if not os.path.exists(download_location):
    os.makedirs(download_location)

# Download the dataset
response = requests.get(url)
with open(download_location + dataset_filename, 'wb') as f:
    f.write(response.content)

# Extract the downloaded file
with tarfile.open(download_location + dataset_filename, 'r:gz') as tar:
    tar.extractall(download_location)

# Define the path to the extracted dataset
dataset_path = download_location + "aclImdb/"

# Function to load the dataset into a Pandas DataFrame
def load_imdb_dataset(data_path):
    texts = []
    labels = []
    for category in ['train', 'test']:
        for sentiment in ['pos', 'neg']:
            folder_path = os.path.join(data_path, category, sentiment)
            for filename in os.listdir(folder_path):
                with open(os.path.join(folder_path, filename), 'r', encoding='utf-8') as file:
                    text = file.read()
                    texts.append(text)
                    labels.append(1 if sentiment == 'pos' else 0)
    return pd.DataFrame({'text': texts, 'label': labels})

# Load the dataset into a Pandas DataFrame
imdb_df = load_imdb_dataset(dataset_path)

# Display the first few rows of the DataFrame
print(imdb_df.head())
# Out:
#                                                 text  label
# 0  I'm intrigued by the strong sense of favour to...      1
# 1  The best film on the battle of San Antonio, Te...      1
# 2  This is how i felt while watching this film. I...      1
# 3  While not as famous as some of their other col...      1
# 4  Unlike many other films, which are disturbing ...      1

# %%
len(imdb_df)
# Out:
# 50000

# %%
from sklearn.model_selection import train_test_split

# Split the dataset into train, test, and validation sets
df_train, test_val_df = train_test_split(imdb_df, test_size=20000, random_state=42)
df_test, df_val = train_test_split(test_val_df, test_size=0.2, random_state=42)

# Display the shapes of the resulting DataFrames
print("Train set shape:", df_train.shape)
print("Test set shape:", df_test.shape)
print("Validation set shape:", df_val.shape)
# Out:
# Train set shape: (30000, 2)
# Test set shape: (16000, 2)
# Validation set shape: (4000, 2)

# %%
df_val.head()
# Out:
#                                                     text  label
# 26891  The film is a remake of a 1956 BBC serial call...      1
# 25024  During World War II, two Byelorussian (Soviet ...      1
# 11666  The information contained in this movie is som...      1
# 40303  and I have seen a lot of films. I saw this in ...      0
# 18010  This su*k! Why do they have to make movies tha...      0

# %%
df_test.head()
# Out:
#                                                     text  label
# 24835  As usual, on IMDb, going by the majority vote ...      0
# 28073  Spoilers in this review! Despite a few highly ...      1
# 31069  I think this movie is the most misunderstood f...      1
# 25736  This film is excellent! Fear of watching docum...      1
# 40229  At the least some of the sitcoms that churn en...      0

# %%
df_train['label'].value_counts()
# Out:
# 0    15084
# 1    14916
# Name: label, dtype: int64

# %% [markdown]
# ## Preprocessing

# %%
# Cleaning/Preprocessing Helper function

def preprocess(s):
  s = re.sub(r'@[a-zA-Z0-9_.]+ ', '', str(s))
  s = re.sub(r'#[a-zA-Z0-9_.]+ ', '', str(s))
  s = re.sub(r'''[^a-zA-Z0-9?. ]+''', '', s)
  s = re.sub(r''''[' ']+''', " ", s)
  s = re.sub(r'(\w)\1{2,}',r'\1',s)
  s = s.lower().strip()
  return s

# %%
df_train['text'] = df_train['text'].apply(preprocess)
df_val['text'] = df_val['text'].apply(preprocess)
df_test['text'] = df_test['text'].apply(preprocess)

# %%
def get_data(df):
  zeros, ones = df[df['label']==0], df[df['label']==1]
  zero_text, zero_labels = zeros['text'].to_numpy(), zeros['label'].to_numpy()
  one_text, one_labels = ones['text'].to_numpy(), ones['label'].to_numpy()
  X, Y = np.concatenate((one_text,zero_text)), np.concatenate((one_labels,zero_labels))
  return X,Y

# %%
X_train,Y_train = get_data(df_train)
X_val,Y_val = get_data(df_val)
X_test,Y_test = get_data(df_test)

# %%
X_train.shape,X_val.shape,X_test.shape
# Out:
# ((30000,), (4000,), (16000,))

# %% [markdown]
# ## Creating the Model

# %%
# Instantiating the Tokenizer and creating sequences
tokenizer = tf.keras.preprocessing.text.Tokenizer(3000,oov_token=1)
tokenizer.fit_on_texts(X_train)
train_seq = tokenizer.texts_to_sequences(X_train)
val_seq = tokenizer.texts_to_sequences(X_val)
test_seq = tokenizer.texts_to_sequences(X_test)

# %%
# Padding all sequences
train_seq = tf.keras.preprocessing.sequence.pad_sequences(train_seq,maxlen=50,padding='post')
val_seq = tf.keras.preprocessing.sequence.pad_sequences(val_seq,maxlen=50,padding='post')
test_seq = tf.keras.preprocessing.sequence.pad_sequences(test_seq,maxlen=50,padding='post')

# %% [markdown]
# ## Creating the Model

# %%
# from tensorflow.keras.layers import Embedding,Dense,LSTM,Flatten,Dropout
# def create_model():
#   model = tf.keras.models.Sequential()
#   model.add(Embedding(3000,64))
#   model.add(LSTM(32))
#   model.add(Flatten())
#   model.add(Dense(64,activation='relu'))
#   model.add(Dropout(0.3))
#   model.add(Dense(32,activation='relu'))
#   model.add(Dropout(0.3))
#   model.add(Dense(4,activation='relu'))
#   model.add(Dense(1,activation='sigmoid'))
#   model.summary()
#   model.compile(optimizer=tf.keras.optimizers.Adam(0.0001),loss=tf.keras.losses.BinaryCrossentropy(),metrics=['accuracy'])
#   return model

# %%
import tensorflow as tf
from tensorflow.keras.layers import Embedding, LSTM, Conv1D, MaxPooling1D, Bidirectional, GlobalMaxPooling1D, Dense, Dropout

def create_model():
    model = tf.keras.models.Sequential()
    model.add(Embedding(input_dim=3000, output_dim=128))

    # Convolutional layers
    model.add(Conv1D(filters=128, kernel_size=3, activation='relu'))
    model.add(MaxPooling1D(pool_size=2))

    # Bidirectional LSTM layer
    model.add(Bidirectional(LSTM(units=64, return_sequences=True)))

    # Global Max Pooling layer
    model.add(GlobalMaxPooling1D())

    # Dense layers
    model.add(Dense(units=256, activation='relu'))
    model.add(Dropout(0.5))

    model.add(Dense(units=128, activation='relu'))
    model.add(Dropout(0.5))

    model.add(Dense(units=64, activation='relu'))
    model.add(Dropout(0.5))

    # Output layer
    model.add(Dense(units=1, activation='sigmoid'))

    model.summary()

    # Compile the model
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
                  loss=tf.keras.losses.BinaryCrossentropy(),
                  metrics=['accuracy'])

    return model

# %% [markdown]
# ## Full Model Training

# %%
# HELPER FUNCTION

def plot(history):
  plt.plot(history.history['loss'])
  plt.plot(history.history['val_loss'])
  plt.legend(['train_loss','val_loss'])
  plt.xlabel('Epochs')
  plt.ylabel('Loss')
  plt.show()

  plt.plot(history.history['accuracy'])
  plt.plot(history.history['val_accuracy'])
  plt.legend(['train_accuracy','val_accuracy'])
  plt.xlabel('Epochs')
  plt.ylabel('Accuracy')
  plt.show()

# %%
def train_full_model(train_seq,Y_train,val_seq,Y_val,test_seq,Y_test):
  model = create_model()
  history = model.fit(train_seq,Y_train,256,15,validation_data=(val_seq,Y_val),callbacks=[tf.keras.callbacks.ModelCheckpoint('FullModelCheckpoint.h5',save_best_only=True,verbose=1),tf.keras.callbacks.EarlyStopping(patience=6,verbose=1)])
  plot(history)
  model = tf.keras.models.load_model('FullModelCheckpoint.h5')
  print(model.evaluate(test_seq,Y_test))
  return model

# %% [markdown]
# ## Active Learning

# %%
# HELPER FUNCTIONS

def append_history(losses,val_losses,acc,val_acc,history):
  losses = losses + history.history['loss']
  val_losses = val_losses + history.history['val_loss']
  acc = acc + history.history['accuracy']
  val_acc = val_acc + history.history['val_accuracy']
  return losses,val_losses,acc,val_acc

def plot_merged_metrics(losses,val_losses,accuracies,val_accuracies):
  plt.plot(losses)
  plt.plot(val_losses)
  plt.legend(['train_loss','val_loss'])
  plt.xlabel('Epochs')
  plt.ylabel('Loss')
  plt.show()

  plt.plot(accuracies)
  plt.plot(val_accuracies)
  plt.legend(['train_accuracy','val_accuracy'])
  plt.xlabel('Epochs')
  plt.ylabel('Accuracy')
  plt.show()

# %%
import numpy as np
import tensorflow as tf
from sklearn.cluster import KMeans

# Set a random seed for reproducibility
np.random.seed(42)
tf.random.set_seed(42)

def diversity_entropy_sampling(model, pool_features, pool_labels, sampling_size=2000, num_clusters=5):
    # Get the penultimate layer activations as features for diversity calculation
    penultimate_layer_model = tf.keras.Model(inputs=model.input, outputs=model.layers[-2].output)
    features = penultimate_layer_model.predict(pool_features)

    # Calculate prediction entropy
    predictions = model.predict(pool_features)
    entropy = -np.sum(predictions * np.log(predictions + 1e-10), axis=1)

    # Apply k-means clustering to the penultimate layer features
    kmeans = KMeans(n_clusters=num_clusters, random_state=42)
    cluster_assignments = kmeans.fit_predict(features)

    # Calculate the diversity scores and entropy scores for each sample in the pool
    diversity_scores = []
    for i in range(pool_features.shape[0]):
        cluster_distance = np.min(np.linalg.norm(features[i] - kmeans.cluster_centers_, axis=1))
        diversity_scores.append(cluster_distance)

    # Normalize diversity scores to be between 0 and 1
    normalized_diversity_scores = (diversity_scores - np.min(diversity_scores)) / (np.max(diversity_scores) - np.min(diversity_scores))

    # Combine diversity and entropy scores
    combined_scores = normalized_diversity_scores + entropy

    # Select samples with high diversity and high entropy
    sample_indices = np.argsort(combined_scores)[-sampling_size:]

    # Convert sample_indices to an array of integers
    sample_indices = np.array(sample_indices, dtype=np.int32)

    # Use boolean indexing to get the selected labels
    selected_labels = pool_labels[sample_indices]
    selected_samples = pool_features[sample_indices]

    return selected_samples, selected_labels


def train_small_models(train_features, train_labels, pool_features, pool_labels, val_seq, Y_val, test_seq, Y_test, iters=3, sampling_size=2000):
    losses, val_losses, accuracies, val_accuracies = [], [], [], []

    for iter_n in range(iters):
        # Create a new model for each iteration
        model = create_model()
        model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

        checkpoint = tf.keras.callbacks.ModelCheckpoint(f'Checkpoint_{iter_n}.h5', save_best_only=True, verbose=1)

        print(f"Starting to train with {train_features.shape[0]} labeled samples")

        history = model.fit(train_features, train_labels, batch_size=256, epochs=15,
                            validation_data=(val_seq, Y_val),
                            callbacks=[checkpoint],
                            shuffle=True)  # Ensure training data shuffling for randomness

        losses, val_losses, accuracies, val_accuracies = append_history(losses, val_losses, accuracies, val_accuracies, history)

        # Evaluate and print accuracy on test data
        test_accuracy = model.evaluate(test_seq, Y_test)[1]
        print(f"Accuracy on test data after iteration {iter_n}: {test_accuracy}, Number of labeled samples: {train_features.shape[0]}")

        # Use diversity and entropy sampling to select samples from the pool
        selected_samples, selected_labels = diversity_entropy_sampling(model, pool_features, pool_labels, sampling_size)

        # Remove the chosen samples from the pool
        pool_features = np.delete(pool_features, selected_samples, axis=0)
        pool_labels = np.delete(pool_labels, selected_samples)

        # Add the sampled entries to the original data
        train_features = np.vstack((train_features, selected_samples))
        train_labels = np.hstack((train_labels, selected_labels))

    plot_merged_metrics(losses, val_losses, accuracies, val_accuracies)

    return model

# %% [markdown]
# ## Ensembling

# %%
# # Splitting Data into Oracle Set(Unlabelled set) and Original Training set
import sklearn.model_selection
train_features,pool_features,train_labels,pool_labels = sklearn.model_selection.train_test_split(train_seq,Y_train,test_size=29000,stratify=Y_train)
train_features.shape,pool_features.shape
# Out:
# ((1000, 50), (29000, 50))

# %%
# Training 3 Active Learning Models for Ensembling
al_model1 = train_small_models(train_features,train_labels,pool_features,pool_labels,val_seq,Y_val,test_seq,Y_test,iters=5, sampling_size=1000)
# al_model2 = train_small_models(train_features,train_labels,pool_features,pool_labels,val_seq,Y_val,test_seq,Y_test)
# al_model3 = train_small_models(train_features,train_labels,pool_features,pool_labels,val_seq,Y_val,test_seq,Y_test)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, None, 128)         384000
#
#  conv1d (Conv1D)             (None, None, 128)         49280
#
#  max_pooling1d (MaxPooling1  (None, None, 128)         0
#  D)
#
#  bidirectional (Bidirection  (None, None, 128)         98816
#  al)
#
#  global_max_pooling1d (Glob  (None, 128)               0
#  alMaxPooling1D)
#
#  dense (Dense)               (None, 256)               33024
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 64)                8256
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 606337 (2.31 MB)
# Trainable params: 606337 (2.31 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Starting to train with 1000 labeled samples
# Epoch 1/15
# 4/4 [==============================] - ETA: 0s - loss: 0.6936 - accuracy: 0.4810
# Epoch 1: val_loss improved from inf to 0.69291, saving model to Checkpoint_0.h5
# 4/4 [==============================] - 9s 980ms/step - loss: 0.6936 - accuracy: 0.4810 - val_loss: 0.6929 - val_accuracy: 0.5132
# Epoch 2/15
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 4/4 [==============================] - ETA: 0s - loss: 0.6934 - accuracy: 0.5050
# Epoch 2: val_loss improved from 0.69291 to 0.69285, saving model to Checkpoint_0.h5
# 4/4 [==============================] - 2s 671ms/step - loss: 0.6934 - accuracy: 0.5050 - val_loss: 0.6928 - val_accuracy: 0.5132
# Epoch 3/15
# 4/4 [==============================] - ETA: 0s - loss: 0.6931 - accuracy: 0.5020
# Epoch 3: val_loss did not improve from 0.69285
# 4/4 [==============================] - 2s 655ms/step - loss: 0.6931 - accuracy: 0.5020 - val_loss: 0.6929 - val_accuracy: 0.5685
# Epoch 4/15
# 4/4 [==============================] - ETA: 0s - loss: 0.6934 - accuracy: 0.5090
# Epoch 4: val_loss did not improve from 0.69285
# 4/4 [==============================] - 4s 1s/step - loss: 0.6934 - accuracy: 0.5090 - val_loss: 0.6930 - val_accuracy: 0.4880
# Epoch 5/15
# 4/4 [==============================] - ETA: 0s - loss: 0.6918 - accuracy: 0.5150
# Epoch 5: val_loss improved from 0.69285 to 0.69257, saving model to Checkpoint_0.h5
# 4/4 [==============================] - 2s 591ms/step - loss: 0.6918 - accuracy: 0.5150 - val_loss: 0.6926 - val_accuracy: 0.5965
# Epoch 6/15
# 4/4 [==============================] - ETA: 0s - loss: 0.6916 - accuracy: 0.5110
# Epoch 6: val_loss improved from 0.69257 to 0.69215, saving model to Checkpoint_0.h5
# 4/4 [==============================] - 2s 598ms/step - loss: 0.6916 - accuracy: 0.5110 - val_loss: 0.6922 - val_accuracy: 0.5763
# Epoch 7/15
# 4/4 [==============================] - ETA: 0s - loss: 0.6903 - accuracy: 0.5310
# Epoch 7: val_loss improved from 0.69215 to 0.69053, saving model to Checkpoint_0.h5
# 4/4 [==============================] - 2s 675ms/step - loss: 0.6903 - accuracy: 0.5310 - val_loss: 0.6905 - val_accuracy: 0.5282
# Epoch 8/15
# 4/4 [==============================] - ETA: 0s - loss: 0.6874 - accuracy: 0.5290
# Epoch 8: val_loss improved from 0.69053 to 0.68745, saving model to Checkpoint_0.h5
# 4/4 [==============================] - 2s 598ms/step - loss: 0.6874 - accuracy: 0.5290 - val_loss: 0.6874 - val_accuracy: 0.5437
# Epoch 9/15
# 4/4 [==============================] - ETA: 0s - loss: 0.6751 - accuracy: 0.6220
# Epoch 9: val_loss improved from 0.68745 to 0.67734, saving model to Checkpoint_0.h5
# 4/4 [==============================] - 3s 865ms/step - loss: 0.6751 - accuracy: 0.6220 - val_loss: 0.6773 - val_accuracy: 0.5813
# Epoch 10/15
# 4/4 [==============================] - ETA: 0s - loss: 0.6542 - accuracy: 0.6670
# Epoch 10: val_loss improved from 0.67734 to 0.65266, saving model to Checkpoint_0.h5
# 4/4 [==============================] - 2s 648ms/step - loss: 0.6542 - accuracy: 0.6670 - val_loss: 0.6527 - val_accuracy: 0.6660
# Epoch 11/15
# 4/4 [==============================] - ETA: 0s - loss: 0.5863 - accuracy: 0.7720
# Epoch 11: val_loss improved from 0.65266 to 0.61933, saving model to Checkpoint_0.h5
# 4/4 [==============================] - 2s 679ms/step - loss: 0.5863 - accuracy: 0.7720 - val_loss: 0.6193 - val_accuracy: 0.6758
# Epoch 12/15
# 4/4 [==============================] - ETA: 0s - loss: 0.4313 - accuracy: 0.8900
# Epoch 12: val_loss did not improve from 0.61933
# 4/4 [==============================] - 2s 626ms/step - loss: 0.4313 - accuracy: 0.8900 - val_loss: 0.6466 - val_accuracy: 0.6798
# Epoch 13/15
# 4/4 [==============================] - ETA: 0s - loss: 0.2347 - accuracy: 0.9390
# Epoch 13: val_loss did not improve from 0.61933
# 4/4 [==============================] - 2s 648ms/step - loss: 0.2347 - accuracy: 0.9390 - val_loss: 1.1358 - val_accuracy: 0.6820
# Epoch 14/15
# 4/4 [==============================] - ETA: 0s - loss: 0.1181 - accuracy: 0.9710
# Epoch 14: val_loss did not improve from 0.61933
# 4/4 [==============================] - 2s 647ms/step - loss: 0.1181 - accuracy: 0.9710 - val_loss: 1.6167 - val_accuracy: 0.6802
# Epoch 15/15
# 4/4 [==============================] - ETA: 0s - loss: 0.1893 - accuracy: 0.9500
# Epoch 15: val_loss did not improve from 0.61933
# 4/4 [==============================] - 3s 857ms/step - loss: 0.1893 - accuracy: 0.9500 - val_loss: 2.6180 - val_accuracy: 0.6712
# 500/500 [==============================] - 8s 16ms/step - loss: 2.6478 - accuracy: 0.6681
# Accuracy on test data after iteration 0: 0.6680625081062317, Number of labeled samples: 1000
# 907/907 [==============================] - 14s 14ms/step
# 907/907 [==============================] - 16s 17ms/step
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, None, 128)         384000
#
#  conv1d_1 (Conv1D)           (None, None, 128)         49280
#
#  max_pooling1d_1 (MaxPoolin  (None, None, 128)         0
#  g1D)
#
#  bidirectional_1 (Bidirecti  (None, None, 128)         98816
#  onal)
#
#  global_max_pooling1d_1 (Gl  (None, 128)               0
#  obalMaxPooling1D)
#
#  dense_4 (Dense)             (None, 256)               33024
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_5 (Dense)             (None, 128)               32896
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  dense_6 (Dense)             (None, 64)                8256
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_7 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 606337 (2.31 MB)
# Trainable params: 606337 (2.31 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Starting to train with 2000 labeled samples
# Epoch 1/15
# 8/8 [==============================] - ETA: 0s - loss: 0.6911 - accuracy: 0.5295
# Epoch 1: val_loss improved from inf to 0.69705, saving model to Checkpoint_1.h5
# 8/8 [==============================] - 10s 554ms/step - loss: 0.6911 - accuracy: 0.5295 - val_loss: 0.6970 - val_accuracy: 0.4868
# Epoch 2/15
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 8/8 [==============================] - ETA: 0s - loss: 0.6837 - accuracy: 0.5645
# Epoch 2: val_loss did not improve from 0.69705
# 8/8 [==============================] - 3s 409ms/step - loss: 0.6837 - accuracy: 0.5645 - val_loss: 0.7111 - val_accuracy: 0.4868
# Epoch 3/15
# 8/8 [==============================] - ETA: 0s - loss: 0.6859 - accuracy: 0.5650
# Epoch 3: val_loss did not improve from 0.69705
# 8/8 [==============================] - 4s 596ms/step - loss: 0.6859 - accuracy: 0.5650 - val_loss: 0.6997 - val_accuracy: 0.4868
# Epoch 4/15
# 8/8 [==============================] - ETA: 0s - loss: 0.6792 - accuracy: 0.5655
# Epoch 4: val_loss did not improve from 0.69705
# 8/8 [==============================] - 3s 412ms/step - loss: 0.6792 - accuracy: 0.5655 - val_loss: 0.6983 - val_accuracy: 0.4868
# Epoch 5/15
# 8/8 [==============================] - ETA: 0s - loss: 0.6669 - accuracy: 0.5655
# Epoch 5: val_loss improved from 0.69705 to 0.69170, saving model to Checkpoint_1.h5
# 8/8 [==============================] - 3s 419ms/step - loss: 0.6669 - accuracy: 0.5655 - val_loss: 0.6917 - val_accuracy: 0.4868
# Epoch 6/15
# 8/8 [==============================] - ETA: 0s - loss: 0.6048 - accuracy: 0.5655
# Epoch 6: val_loss improved from 0.69170 to 0.65164, saving model to Checkpoint_1.h5
# 8/8 [==============================] - 3s 393ms/step - loss: 0.6048 - accuracy: 0.5655 - val_loss: 0.6516 - val_accuracy: 0.4868
# Epoch 7/15
# 8/8 [==============================] - ETA: 0s - loss: 0.4920 - accuracy: 0.6550
# Epoch 7: val_loss improved from 0.65164 to 0.61830, saving model to Checkpoint_1.h5
# 8/8 [==============================] - 4s 558ms/step - loss: 0.4920 - accuracy: 0.6550 - val_loss: 0.6183 - val_accuracy: 0.7265
# Epoch 8/15
# 8/8 [==============================] - ETA: 0s - loss: 0.3905 - accuracy: 0.8705
# Epoch 8: val_loss did not improve from 0.61830
# 8/8 [==============================] - 3s 383ms/step - loss: 0.3905 - accuracy: 0.8705 - val_loss: 0.6475 - val_accuracy: 0.7243
# Epoch 9/15
# 8/8 [==============================] - ETA: 0s - loss: 0.2480 - accuracy: 0.9235
# Epoch 9: val_loss did not improve from 0.61830
# 8/8 [==============================] - 3s 408ms/step - loss: 0.2480 - accuracy: 0.9235 - val_loss: 0.9515 - val_accuracy: 0.7203
# Epoch 10/15
# 8/8 [==============================] - ETA: 0s - loss: 0.1399 - accuracy: 0.9600
# Epoch 10: val_loss did not improve from 0.61830
# 8/8 [==============================] - 3s 410ms/step - loss: 0.1399 - accuracy: 0.9600 - val_loss: 0.8483 - val_accuracy: 0.7270
# Epoch 11/15
# 8/8 [==============================] - ETA: 0s - loss: 0.0866 - accuracy: 0.9795
# Epoch 11: val_loss did not improve from 0.61830
# 8/8 [==============================] - 4s 562ms/step - loss: 0.0866 - accuracy: 0.9795 - val_loss: 1.2136 - val_accuracy: 0.7300
# Epoch 12/15
# 8/8 [==============================] - ETA: 0s - loss: 0.0656 - accuracy: 0.9810
# Epoch 12: val_loss did not improve from 0.61830
# 8/8 [==============================] - 3s 410ms/step - loss: 0.0656 - accuracy: 0.9810 - val_loss: 1.4545 - val_accuracy: 0.7270
# Epoch 13/15
# 8/8 [==============================] - ETA: 0s - loss: 0.0291 - accuracy: 0.9920
# Epoch 13: val_loss did not improve from 0.61830
# 8/8 [==============================] - 3s 411ms/step - loss: 0.0291 - accuracy: 0.9920 - val_loss: 1.4897 - val_accuracy: 0.7278
# Epoch 14/15
# 8/8 [==============================] - ETA: 0s - loss: 0.0197 - accuracy: 0.9950
# Epoch 14: val_loss did not improve from 0.61830
# 8/8 [==============================] - 3s 408ms/step - loss: 0.0197 - accuracy: 0.9950 - val_loss: 1.8180 - val_accuracy: 0.7200
# Epoch 15/15
# 8/8 [==============================] - ETA: 0s - loss: 0.0145 - accuracy: 0.9955
# Epoch 15: val_loss did not improve from 0.61830
# 8/8 [==============================] - 4s 527ms/step - loss: 0.0145 - accuracy: 0.9955 - val_loss: 2.2279 - val_accuracy: 0.7005
# 500/500 [==============================] - 8s 16ms/step - loss: 2.1013 - accuracy: 0.7128
# Accuracy on test data after iteration 1: 0.7128124833106995, Number of labeled samples: 2000
# 824/824 [==============================] - 15s 16ms/step
# 824/824 [==============================] - 13s 15ms/step
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, None, 128)         384000
#
#  conv1d_2 (Conv1D)           (None, None, 128)         49280
#
#  max_pooling1d_2 (MaxPoolin  (None, None, 128)         0
#  g1D)
#
#  bidirectional_2 (Bidirecti  (None, None, 128)         98816
#  onal)
#
#  global_max_pooling1d_2 (Gl  (None, 128)               0
#  obalMaxPooling1D)
#
#  dense_8 (Dense)             (None, 256)               33024
#
#  dropout_6 (Dropout)         (None, 256)               0
#
#  dense_9 (Dense)             (None, 128)               32896
#
#  dropout_7 (Dropout)         (None, 128)               0
#
#  dense_10 (Dense)            (None, 64)                8256
#
#  dropout_8 (Dropout)         (None, 64)                0
#
#  dense_11 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 606337 (2.31 MB)
# Trainable params: 606337 (2.31 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Starting to train with 3000 labeled samples
# Epoch 1/15
# 12/12 [==============================] - ETA: 0s - loss: 0.6933 - accuracy: 0.5157
# Epoch 1: val_loss improved from inf to 0.69392, saving model to Checkpoint_2.h5
# 12/12 [==============================] - 11s 445ms/step - loss: 0.6933 - accuracy: 0.5157 - val_loss: 0.6939 - val_accuracy: 0.4868
# Epoch 2/15
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 12/12 [==============================] - ETA: 0s - loss: 0.6930 - accuracy: 0.5123
# Epoch 2: val_loss improved from 0.69392 to 0.69322, saving model to Checkpoint_2.h5
# 12/12 [==============================] - 4s 324ms/step - loss: 0.6930 - accuracy: 0.5123 - val_loss: 0.6932 - val_accuracy: 0.4868
# Epoch 3/15
# 12/12 [==============================] - ETA: 0s - loss: 0.6902 - accuracy: 0.5143
# Epoch 3: val_loss improved from 0.69322 to 0.69062, saving model to Checkpoint_2.h5
# 12/12 [==============================] - 5s 472ms/step - loss: 0.6902 - accuracy: 0.5143 - val_loss: 0.6906 - val_accuracy: 0.4868
# Epoch 4/15
# 12/12 [==============================] - ETA: 0s - loss: 0.6690 - accuracy: 0.5563
# Epoch 4: val_loss improved from 0.69062 to 0.64202, saving model to Checkpoint_2.h5
# 12/12 [==============================] - 4s 334ms/step - loss: 0.6690 - accuracy: 0.5563 - val_loss: 0.6420 - val_accuracy: 0.6180
# Epoch 5/15
# 12/12 [==============================] - ETA: 0s - loss: 0.5699 - accuracy: 0.7300
# Epoch 5: val_loss improved from 0.64202 to 0.55867, saving model to Checkpoint_2.h5
# 12/12 [==============================] - 4s 345ms/step - loss: 0.5699 - accuracy: 0.7300 - val_loss: 0.5587 - val_accuracy: 0.7293
# Epoch 6/15
# 12/12 [==============================] - ETA: 0s - loss: 0.3925 - accuracy: 0.8417
# Epoch 6: val_loss did not improve from 0.55867
# 12/12 [==============================] - 6s 527ms/step - loss: 0.3925 - accuracy: 0.8417 - val_loss: 0.5782 - val_accuracy: 0.7520
# Epoch 7/15
# 12/12 [==============================] - ETA: 0s - loss: 0.2443 - accuracy: 0.9137
# Epoch 7: val_loss did not improve from 0.55867
# 12/12 [==============================] - 4s 343ms/step - loss: 0.2443 - accuracy: 0.9137 - val_loss: 0.8151 - val_accuracy: 0.7487
# Epoch 8/15
# 12/12 [==============================] - ETA: 0s - loss: 0.1462 - accuracy: 0.9577
# Epoch 8: val_loss did not improve from 0.55867
# 12/12 [==============================] - 4s 338ms/step - loss: 0.1462 - accuracy: 0.9577 - val_loss: 0.9298 - val_accuracy: 0.7477
# Epoch 9/15
# 12/12 [==============================] - ETA: 0s - loss: 0.0704 - accuracy: 0.9803
# Epoch 9: val_loss did not improve from 0.55867
# 12/12 [==============================] - 5s 448ms/step - loss: 0.0704 - accuracy: 0.9803 - val_loss: 1.6790 - val_accuracy: 0.7228
# Epoch 10/15
# 12/12 [==============================] - ETA: 0s - loss: 0.0458 - accuracy: 0.9863
# Epoch 10: val_loss did not improve from 0.55867
# 12/12 [==============================] - 4s 334ms/step - loss: 0.0458 - accuracy: 0.9863 - val_loss: 1.3829 - val_accuracy: 0.7370
# Epoch 11/15
# 12/12 [==============================] - ETA: 0s - loss: 0.0261 - accuracy: 0.9933
# Epoch 11: val_loss did not improve from 0.55867
# 12/12 [==============================] - 4s 339ms/step - loss: 0.0261 - accuracy: 0.9933 - val_loss: 1.7212 - val_accuracy: 0.7387
# Epoch 12/15
# 12/12 [==============================] - ETA: 0s - loss: 0.0125 - accuracy: 0.9977
# Epoch 12: val_loss did not improve from 0.55867
# 12/12 [==============================] - 5s 446ms/step - loss: 0.0125 - accuracy: 0.9977 - val_loss: 2.1682 - val_accuracy: 0.7340
# Epoch 13/15
# 12/12 [==============================] - ETA: 0s - loss: 0.0555 - accuracy: 0.9807
# Epoch 13: val_loss did not improve from 0.55867
# 12/12 [==============================] - 4s 331ms/step - loss: 0.0555 - accuracy: 0.9807 - val_loss: 1.6669 - val_accuracy: 0.7308
# Epoch 14/15
# 12/12 [==============================] - ETA: 0s - loss: 0.0319 - accuracy: 0.9923
# Epoch 14: val_loss did not improve from 0.55867
# 12/12 [==============================] - 4s 338ms/step - loss: 0.0319 - accuracy: 0.9923 - val_loss: 1.6174 - val_accuracy: 0.7315
# Epoch 15/15
# 12/12 [==============================] - ETA: 0s - loss: 0.0240 - accuracy: 0.9900
# Epoch 15: val_loss did not improve from 0.55867
# 12/12 [==============================] - 5s 446ms/step - loss: 0.0240 - accuracy: 0.9900 - val_loss: 1.9669 - val_accuracy: 0.7337
# 500/500 [==============================] - 8s 15ms/step - loss: 1.7999 - accuracy: 0.7480
# Accuracy on test data after iteration 2: 0.7480000257492065, Number of labeled samples: 3000
# 740/740 [==============================] - 12s 14ms/step
# 740/740 [==============================] - 12s 14ms/step
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_3 (Embedding)     (None, None, 128)         384000
#
#  conv1d_3 (Conv1D)           (None, None, 128)         49280
#
#  max_pooling1d_3 (MaxPoolin  (None, None, 128)         0
#  g1D)
#
#  bidirectional_3 (Bidirecti  (None, None, 128)         98816
#  onal)
#
#  global_max_pooling1d_3 (Gl  (None, 128)               0
#  obalMaxPooling1D)
#
#  dense_12 (Dense)            (None, 256)               33024
#
#  dropout_9 (Dropout)         (None, 256)               0
#
#  dense_13 (Dense)            (None, 128)               32896
#
#  dropout_10 (Dropout)        (None, 128)               0
#
#  dense_14 (Dense)            (None, 64)                8256
#
#  dropout_11 (Dropout)        (None, 64)                0
#
#  dense_15 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 606337 (2.31 MB)
# Trainable params: 606337 (2.31 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Starting to train with 4000 labeled samples
# Epoch 1/15
# 16/16 [==============================] - ETA: 0s - loss: 0.6936 - accuracy: 0.4990
# Epoch 1: val_loss improved from inf to 0.69279, saving model to Checkpoint_3.h5
# 16/16 [==============================] - 12s 461ms/step - loss: 0.6936 - accuracy: 0.4990 - val_loss: 0.6928 - val_accuracy: 0.5132
# Epoch 2/15
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 16/16 [==============================] - ETA: 0s - loss: 0.6930 - accuracy: 0.5120
# Epoch 2: val_loss improved from 0.69279 to 0.69212, saving model to Checkpoint_3.h5
# 16/16 [==============================] - 5s 297ms/step - loss: 0.6930 - accuracy: 0.5120 - val_loss: 0.6921 - val_accuracy: 0.5132
# Epoch 3/15
# 16/16 [==============================] - ETA: 0s - loss: 0.6909 - accuracy: 0.5395
# Epoch 3: val_loss improved from 0.69212 to 0.68423, saving model to Checkpoint_3.h5
# 16/16 [==============================] - 5s 312ms/step - loss: 0.6909 - accuracy: 0.5395 - val_loss: 0.6842 - val_accuracy: 0.5835
# Epoch 4/15
# 16/16 [==============================] - ETA: 0s - loss: 0.6226 - accuracy: 0.6850
# Epoch 4: val_loss improved from 0.68423 to 0.54356, saving model to Checkpoint_3.h5
# 16/16 [==============================] - 6s 399ms/step - loss: 0.6226 - accuracy: 0.6850 - val_loss: 0.5436 - val_accuracy: 0.7300
# Epoch 5/15
# 16/16 [==============================] - ETA: 0s - loss: 0.4248 - accuracy: 0.8180
# Epoch 5: val_loss improved from 0.54356 to 0.50814, saving model to Checkpoint_3.h5
# 16/16 [==============================] - 5s 315ms/step - loss: 0.4248 - accuracy: 0.8180 - val_loss: 0.5081 - val_accuracy: 0.7665
# Epoch 6/15
# 16/16 [==============================] - ETA: 0s - loss: 0.2693 - accuracy: 0.8988
# Epoch 6: val_loss did not improve from 0.50814
# 16/16 [==============================] - 6s 384ms/step - loss: 0.2693 - accuracy: 0.8988 - val_loss: 0.6604 - val_accuracy: 0.7592
# Epoch 7/15
# 16/16 [==============================] - ETA: 0s - loss: 0.1675 - accuracy: 0.9477
# Epoch 7: val_loss did not improve from 0.50814
# 16/16 [==============================] - 5s 313ms/step - loss: 0.1675 - accuracy: 0.9477 - val_loss: 0.9420 - val_accuracy: 0.7500
# Epoch 8/15
# 16/16 [==============================] - ETA: 0s - loss: 0.0875 - accuracy: 0.9765
# Epoch 8: val_loss did not improve from 0.50814
# 16/16 [==============================] - 5s 316ms/step - loss: 0.0875 - accuracy: 0.9765 - val_loss: 1.2212 - val_accuracy: 0.7477
# Epoch 9/15
# 16/16 [==============================] - ETA: 0s - loss: 0.0414 - accuracy: 0.9898
# Epoch 9: val_loss did not improve from 0.50814
# 16/16 [==============================] - 6s 357ms/step - loss: 0.0414 - accuracy: 0.9898 - val_loss: 1.5679 - val_accuracy: 0.7490
# Epoch 10/15
# 16/16 [==============================] - ETA: 0s - loss: 0.0562 - accuracy: 0.9805
# Epoch 10: val_loss did not improve from 0.50814
# 16/16 [==============================] - 5s 309ms/step - loss: 0.0562 - accuracy: 0.9805 - val_loss: 1.3248 - val_accuracy: 0.7460
# Epoch 11/15
# 16/16 [==============================] - ETA: 0s - loss: 0.0299 - accuracy: 0.9910
# Epoch 11: val_loss did not improve from 0.50814
# 16/16 [==============================] - 7s 460ms/step - loss: 0.0299 - accuracy: 0.9910 - val_loss: 1.6081 - val_accuracy: 0.7617
# Epoch 12/15
# 16/16 [==============================] - ETA: 0s - loss: 0.0372 - accuracy: 0.9872
# Epoch 12: val_loss did not improve from 0.50814
# 16/16 [==============================] - 5s 313ms/step - loss: 0.0372 - accuracy: 0.9872 - val_loss: 1.7964 - val_accuracy: 0.7525
# Epoch 13/15
# 16/16 [==============================] - ETA: 0s - loss: 0.0260 - accuracy: 0.9925
# Epoch 13: val_loss did not improve from 0.50814
# 16/16 [==============================] - 5s 316ms/step - loss: 0.0260 - accuracy: 0.9925 - val_loss: 1.7376 - val_accuracy: 0.7525
# Epoch 14/15
# 16/16 [==============================] - ETA: 0s - loss: 0.0154 - accuracy: 0.9952
# Epoch 14: val_loss did not improve from 0.50814
# 16/16 [==============================] - 6s 360ms/step - loss: 0.0154 - accuracy: 0.9952 - val_loss: 2.2596 - val_accuracy: 0.7362
# Epoch 15/15
# 16/16 [==============================] - ETA: 0s - loss: 0.0127 - accuracy: 0.9960
# Epoch 15: val_loss did not improve from 0.50814
# 16/16 [==============================] - 5s 312ms/step - loss: 0.0127 - accuracy: 0.9960 - val_loss: 1.9427 - val_accuracy: 0.7455
# 500/500 [==============================] - 8s 17ms/step - loss: 1.8598 - accuracy: 0.7511
# Accuracy on test data after iteration 3: 0.7511249780654907, Number of labeled samples: 4000
# 657/657 [==============================] - 13s 17ms/step
# 657/657 [==============================] - 12s 17ms/step
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_4 (Embedding)     (None, None, 128)         384000
#
#  conv1d_4 (Conv1D)           (None, None, 128)         49280
#
#  max_pooling1d_4 (MaxPoolin  (None, None, 128)         0
#  g1D)
#
#  bidirectional_4 (Bidirecti  (None, None, 128)         98816
#  onal)
#
#  global_max_pooling1d_4 (Gl  (None, 128)               0
#  obalMaxPooling1D)
#
#  dense_16 (Dense)            (None, 256)               33024
#
#  dropout_12 (Dropout)        (None, 256)               0
#
#  dense_17 (Dense)            (None, 128)               32896
#
#  dropout_13 (Dropout)        (None, 128)               0
#
#  dense_18 (Dense)            (None, 64)                8256
#
#  dropout_14 (Dropout)        (None, 64)                0
#
#  dense_19 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 606337 (2.31 MB)
# Trainable params: 606337 (2.31 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Starting to train with 5000 labeled samples
# Epoch 1/15
# 20/20 [==============================] - ETA: 0s - loss: 0.6929 - accuracy: 0.5018
# Epoch 1: val_loss improved from inf to 0.69235, saving model to Checkpoint_4.h5
# 20/20 [==============================] - 13s 358ms/step - loss: 0.6929 - accuracy: 0.5018 - val_loss: 0.6923 - val_accuracy: 0.5132
# Epoch 2/15
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 20/20 [==============================] - ETA: 0s - loss: 0.6924 - accuracy: 0.5150
# Epoch 2: val_loss improved from 0.69235 to 0.68841, saving model to Checkpoint_4.h5
# 20/20 [==============================] - 7s 379ms/step - loss: 0.6924 - accuracy: 0.5150 - val_loss: 0.6884 - val_accuracy: 0.5477
# Epoch 3/15
# 20/20 [==============================] - ETA: 0s - loss: 0.6464 - accuracy: 0.6260
# Epoch 3: val_loss improved from 0.68841 to 0.54843, saving model to Checkpoint_4.h5
# 20/20 [==============================] - 6s 284ms/step - loss: 0.6464 - accuracy: 0.6260 - val_loss: 0.5484 - val_accuracy: 0.7310
# Epoch 4/15
# 20/20 [==============================] - ETA: 0s - loss: 0.4271 - accuracy: 0.8056
# Epoch 4: val_loss improved from 0.54843 to 0.48157, saving model to Checkpoint_4.h5
# 20/20 [==============================] - 8s 388ms/step - loss: 0.4271 - accuracy: 0.8056 - val_loss: 0.4816 - val_accuracy: 0.7760
# Epoch 5/15
# 20/20 [==============================] - ETA: 0s - loss: 0.2925 - accuracy: 0.8820
# Epoch 5: val_loss did not improve from 0.48157
# 20/20 [==============================] - 6s 290ms/step - loss: 0.2925 - accuracy: 0.8820 - val_loss: 0.5784 - val_accuracy: 0.7707
# Epoch 6/15
# 20/20 [==============================] - ETA: 0s - loss: 0.1821 - accuracy: 0.9388
# Epoch 6: val_loss did not improve from 0.48157
# 20/20 [==============================] - 8s 401ms/step - loss: 0.1821 - accuracy: 0.9388 - val_loss: 0.6785 - val_accuracy: 0.7657
# Epoch 7/15
# 20/20 [==============================] - ETA: 0s - loss: 0.1291 - accuracy: 0.9558
# Epoch 7: val_loss did not improve from 0.48157
# 20/20 [==============================] - 6s 278ms/step - loss: 0.1291 - accuracy: 0.9558 - val_loss: 1.0216 - val_accuracy: 0.7582
# Epoch 8/15
# 20/20 [==============================] - ETA: 0s - loss: 0.0679 - accuracy: 0.9796
# Epoch 8: val_loss did not improve from 0.48157
# 20/20 [==============================] - 8s 416ms/step - loss: 0.0679 - accuracy: 0.9796 - val_loss: 1.3744 - val_accuracy: 0.7570
# Epoch 9/15
# 20/20 [==============================] - ETA: 0s - loss: 0.0316 - accuracy: 0.9906
# Epoch 9: val_loss did not improve from 0.48157
# 20/20 [==============================] - 6s 281ms/step - loss: 0.0316 - accuracy: 0.9906 - val_loss: 1.8537 - val_accuracy: 0.7630
# Epoch 10/15
# 20/20 [==============================] - ETA: 0s - loss: 0.0220 - accuracy: 0.9930
# Epoch 10: val_loss did not improve from 0.48157
# 20/20 [==============================] - 8s 390ms/step - loss: 0.0220 - accuracy: 0.9930 - val_loss: 1.8334 - val_accuracy: 0.7607
# Epoch 11/15
# 20/20 [==============================] - ETA: 0s - loss: 0.0265 - accuracy: 0.9920
# Epoch 11: val_loss did not improve from 0.48157
# 20/20 [==============================] - 6s 292ms/step - loss: 0.0265 - accuracy: 0.9920 - val_loss: 2.0291 - val_accuracy: 0.7315
# Epoch 12/15
# 20/20 [==============================] - ETA: 0s - loss: 0.0425 - accuracy: 0.9858
# Epoch 12: val_loss did not improve from 0.48157
# 20/20 [==============================] - 7s 345ms/step - loss: 0.0425 - accuracy: 0.9858 - val_loss: 1.5996 - val_accuracy: 0.7545
# Epoch 13/15
# 20/20 [==============================] - ETA: 0s - loss: 0.0130 - accuracy: 0.9970
# Epoch 13: val_loss did not improve from 0.48157
# 20/20 [==============================] - 6s 281ms/step - loss: 0.0130 - accuracy: 0.9970 - val_loss: 2.3051 - val_accuracy: 0.7510
# Epoch 14/15
# 20/20 [==============================] - ETA: 0s - loss: 0.0056 - accuracy: 0.9986
# Epoch 14: val_loss did not improve from 0.48157
# 20/20 [==============================] - 8s 391ms/step - loss: 0.0056 - accuracy: 0.9986 - val_loss: 2.6164 - val_accuracy: 0.7485
# Epoch 15/15
# 20/20 [==============================] - ETA: 0s - loss: 0.0022 - accuracy: 0.9990
# Epoch 15: val_loss did not improve from 0.48157
# 20/20 [==============================] - 6s 279ms/step - loss: 0.0022 - accuracy: 0.9990 - val_loss: 2.8937 - val_accuracy: 0.7538
# 500/500 [==============================] - 8s 17ms/step - loss: 2.7534 - accuracy: 0.7679
# Accuracy on test data after iteration 4: 0.7678750157356262, Number of labeled samples: 5000
# 574/574 [==============================] - 10s 16ms/step
# 574/574 [==============================] - 9s 15ms/step
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
